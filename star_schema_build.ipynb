# %%
#imports
import numpy as np
import pandas as pd
import os
import glob
import datetime

# %%
# print switch
switch  =  True

# %%
# Get files and filepaths
directory = '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/'

covid_case_files = list(glob.glob(os.path.join(directory,'*.*')))
covid_case_files.sort()

# %%
######
covid_case_files
# Out:
# ['/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/PRM-EST2020.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/US_fips_codes.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/american-samoa-phc-table01.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/co-est2021-alldata.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/commonwealth-northern-mariana-islands-phc-table01.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/guam-phc-table01.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/island_populations.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us-counties-2020.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us-counties-2021.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us-counties-2022.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us-counties-2023.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us-states.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us-virgin-islands-phc-table01.csv',
#  '/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/us.csv']

# %%
# download all 4 csv files and append to DF
all_counties_df = pd.DataFrame(columns=['date','state','county','fips','cases','deaths'])

for file in covid_case_files[7:11]:
    all_counties_df = pd.concat([all_counties_df, pd.read_csv(file, parse_dates=['date'])], ignore_index=True)

len(all_counties_df)
# Out:
# 3525161

# %%
######
all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3525161 entries, 0 to 3525160
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   fips    float64
#  4   cases   object
#  5   deaths  float64
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 161.4+ MB

# %%
#####
#  all_counties_df = all_counties_df.astype(columns_and_types)
all_counties_df.head()
# Out:
#         date       state     county     fips cases  deaths
# 0 2020-01-21  Washington  Snohomish  53061.0     1     0.0
# 1 2020-01-22  Washington  Snohomish  53061.0     1     0.0
# 2 2020-01-23  Washington  Snohomish  53061.0     1     0.0
# 3 2020-01-24    Illinois       Cook  17031.0     1     0.0
# 4 2020-01-24  Washington  Snohomish  53061.0     1     0.0

# %%
#######
# all_counties_df.fips = '0' + all_counties_df.fips
# all_counties_df.head()

# %%
# convert cases to numeric
all_counties_df.cases = pd.to_numeric(all_counties_df.cases)

# %%
######
all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3525161 entries, 0 to 3525160
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   fips    float64
#  4   cases   int64
#  5   deaths  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 161.4+ MB

# %%
# get unique values from county and state columns
null_counties = all_counties_df.county.loc[all_counties_df.fips.isnull()].unique()

null_states = all_counties_df.state.loc[all_counties_df.fips.isnull()].unique()

print(null_counties,'',null_states, sep='\n')
# Out:
# ['New York City' 'Unknown' 'Kansas City' 'Joplin']
#
# ['New York' 'Rhode Island' 'New Jersey' 'Puerto Rico' 'Virgin Islands'
#  'Guam' 'Maine' 'Massachusetts' 'Louisiana' 'Kentucky' 'Nevada'
#  'Tennessee' 'Arkansas' 'Georgia' 'Missouri' 'Minnesota' 'California'
#  'Colorado' 'Florida' 'Hawaii' 'Illinois' 'Vermont' 'Arizona' 'Michigan'
#  'Texas' 'Virginia' 'Washington' 'Utah' 'Idaho' 'Mississippi'
#  'Northern Mariana Islands' 'Connecticut' 'Nebraska' 'Montana'
#  'Pennsylvania' 'Indiana' 'Iowa' 'Maryland' 'Oklahoma' 'West Virginia'
#  'Alaska' 'New Mexico' 'New Hampshire' 'South Dakota' 'Kansas' 'Wyoming'
#  'Delaware' 'North Dakota' 'Ohio' 'Wisconsin' 'South Carolina' 'Oregon'
#  'North Carolina' 'American Samoa' 'Alabama']

# %%
# view nulls in all_counties
all_counties_df.loc[all_counties_df.fips.isnull()][1000:1060]
# Out:
#             date                     state         county  fips   cases  \
# 78132 2020-04-21                      Utah        Unknown   NaN       0
# 78148 2020-04-21                   Vermont        Unknown   NaN       3
# 78155 2020-04-21            Virgin Islands        Unknown   NaN       0
# 78547 2020-04-22                   Arizona        Unknown   NaN       0
# 78616 2020-04-22                  Arkansas        Unknown   NaN     113
# 78728 2020-04-22                  Colorado        Unknown   NaN      95
# 78739 2020-04-22               Connecticut        Unknown   NaN     550
# 78744 2020-04-22                  Delaware        Unknown   NaN      28
# 78809 2020-04-22                   Florida        Unknown   NaN       0
# 78956 2020-04-22                   Georgia        Unknown   NaN     576
# 78972 2020-04-22                      Guam        Unknown   NaN     911
# 79094 2020-04-22                  Illinois        Unknown   NaN     228
# 79272 2020-04-22                      Iowa        Unknown   NaN       0
# 79456 2020-04-22                  Kentucky        Unknown   NaN      36
# 79519 2020-04-22                 Louisiana        Unknown   NaN     119
# 79541 2020-04-22                     Maine        Unknown   NaN       2
# 79566 2020-04-22                  Maryland        Unknown   NaN       8
# 79583 2020-04-22             Massachusetts        Unknown   NaN     854
# 79734 2020-04-22                 Minnesota        Unknown   NaN       4
# 79869 2020-04-22                  Missouri    Kansas City   NaN     448
# 79916 2020-04-22                  Missouri        Unknown   NaN       3
# 80001 2020-04-22                  Nebraska        Unknown   NaN      10
# 80016 2020-04-22                    Nevada        Unknown   NaN       9
# 80029 2020-04-22             New Hampshire        Unknown   NaN      17
# 80050 2020-04-22                New Jersey        Unknown   NaN    1045
# 80107 2020-04-22                  New York  New York City   NaN  146787
# 80263 2020-04-22  Northern Mariana Islands        Unknown   NaN      14
# 80518 2020-04-22               Puerto Rico        Unknown   NaN     915
# 80523 2020-04-22              Rhode Island        Unknown   NaN    1341
# 80924 2020-04-22                      Utah        Unknown   NaN       0
# 80940 2020-04-22                   Vermont        Unknown   NaN       3
# 80947 2020-04-22            Virgin Islands        Unknown   NaN       0
# 81340 2020-04-23                   Arizona        Unknown   NaN       0
# 81410 2020-04-23                  Arkansas        Unknown   NaN     127
# 81522 2020-04-23                  Colorado        Unknown   NaN     108
# 81533 2020-04-23               Connecticut        Unknown   NaN     522
# 81538 2020-04-23                  Delaware        Unknown   NaN       3
# 81749 2020-04-23                   Georgia        Unknown   NaN     361
# 81765 2020-04-23                      Guam        Unknown   NaN     979
# 81887 2020-04-23                  Illinois        Unknown   NaN     192
# 82315 2020-04-23                 Louisiana        Unknown   NaN     121
# 82361 2020-04-23                  Maryland        Unknown   NaN       5
# 82378 2020-04-23             Massachusetts        Unknown   NaN     737
# 82455 2020-04-23                  Michigan        Unknown   NaN      71
# 82530 2020-04-23                 Minnesota        Unknown   NaN       3
# 82665 2020-04-23                  Missouri    Kansas City   NaN     461
# 82712 2020-04-23                  Missouri        Unknown   NaN       2
# 82799 2020-04-23                  Nebraska        Unknown   NaN       8
# 82814 2020-04-23                    Nevada        Unknown   NaN       1
# 82827 2020-04-23             New Hampshire        Unknown   NaN      11
# 82848 2020-04-23                New Jersey        Unknown   NaN    1108
# 82906 2020-04-23                  New York  New York City   NaN  150327
# 83062 2020-04-23  Northern Mariana Islands        Unknown   NaN      14
# 83317 2020-04-23               Puerto Rico        Unknown   NaN    1230
# 83322 2020-04-23              Rhode Island        Unknown   NaN    1756
# 83725 2020-04-23                      Utah        Unknown   NaN       0
# 83741 2020-04-23                   Vermont        Unknown   NaN       3
# 83748 2020-04-23            Virgin Islands        Unknown   NaN       0
# 84210 2020-04-24                  Arkansas        Unknown   NaN     182
# 84322 2020-04-24                  Colorado        Unknown   NaN     103
#
#         deaths
# 78132      2.0
# 78148      0.0
# 78155      3.0
# 78547      5.0
# 78616      0.0
# 78728      0.0
# 78739      7.0
# 78744      0.0
# 78809     34.0
# 78956      0.0
# 78972      6.0
# 79094      1.0
# 79272      2.0
# 79456      0.0
# 79519     60.0
# 79541      0.0
# 79566    102.0
# 79583      9.0
# 79734      0.0
# 79869     13.0
# 79916      0.0
# 80001      0.0
# 80016     11.0
# 80029      1.0
# 80050      2.0
# 80107  14959.0
# 80263      2.0
# 80518     46.0
# 80523    161.0
# 80924      2.0
# 80940      0.0
# 80947      3.0
# 81340      5.0
# 81410      0.0
# 81522      0.0
# 81533      6.0
# 81538      0.0
# 81749      0.0
# 81765      6.0
# 81887      0.0
# 82315     59.0
# 82361    102.0
# 82378     10.0
# 82455      2.0
# 82530      0.0
# 82665     14.0
# 82712      0.0
# 82799      1.0
# 82814      5.0
# 82827      1.0
# 82848      2.0
# 82906  15361.0
# 83062      2.0
# 83317     69.0
# 83322    169.0
# 83725      1.0
# 83741      0.0
# 83748      3.0
# 84210      0.0
# 84322      0.0

# %%
# find nulls in deaths (Puerto Rico)
all_counties_df.county.loc[all_counties_df.deaths.isnull()].unique()
# Out:
# array(['Adjuntas', 'Aguada', 'Aguadilla', 'Aguas Buenas', 'Aibonito',
#        'Anasco', 'Arecibo', 'Arroyo', 'Barceloneta', 'Barranquitas',
#        'Bayamon', 'Cabo Rojo', 'Caguas', 'Camuy', 'Canovanas', 'Carolina',
#        'Catano', 'Cayey', 'Ceiba', 'Ciales', 'Cidra', 'Coamo', 'Comerio',
#        'Corozal', 'Dorado', 'Fajardo', 'Florida', 'Guanica', 'Guayama',
#        'Guayanilla', 'Guaynabo', 'Gurabo', 'Hatillo', 'Hormigueros',
#        'Humacao', 'Isabela', 'Jayuya', 'Juana Diaz', 'Juncos', 'Lajas',
#        'Lares', 'Las Marias', 'Las Piedras', 'Loiza', 'Luquillo',
#        'Manati', 'Maunabo', 'Mayaguez', 'Moca', 'Morovis', 'Naguabo',
#        'Naranjito', 'Orocovis', 'Patillas', 'Penuelas', 'Ponce',
#        'Quebradillas', 'Rincon', 'Rio Grande', 'Sabana Grande', 'Salinas',
#        'San German', 'San Juan', 'San Lorenzo', 'San Sebastian',
#        'Santa Isabel', 'Toa Alta', 'Toa Baja', 'Trujillo Alto', 'Utuado',
#        'Vega Alta', 'Vega Baja', 'Villalba', 'Yabucoa', 'Yauco',
#        'Vieques', 'Maricao', 'Culebra'], dtype=object)

# %%
#######
all_counties_df.loc[all_counties_df.deaths.isnull()].state.unique()
# Out:
# array(['Puerto Rico'], dtype=object)

# %%
# convert deaths nulls to 0 and convert to int
all_counties_df = all_counties_df.fillna(0).astype({'fips':'int','deaths':'int'})
all_counties_df.isnull().sum()
# Out:
# date      0
# state     0
# county    0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %%
########
all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3525161 entries, 0 to 3525160
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   fips    int64
#  4   cases   int64
#  5   deaths  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 161.4+ MB

# %% [markdown]
# State Id for dimState table

# %%
########
# states = list(all_counties_df.state.unique())
# states.sort()
# states = list(states)
# states.insert(0,'Unknown')
# states

# %%
#########
# state_id_dict = {k: v for k, v in zip(np.arange(1, len(states), states))}
# state_id_dict = dict(zip(states, np.arange(0,len(states))))
# state_id_dict

# %%
######
# counties = list(all_counties_df.county.unique())
# counties.sort()
# counties = list(counties)
# unknown = counties.pop(1771)
# counties.insert(0,unknown)
# counties

# %%
#####
# county_id_dict = dict(zip(counties, np.arange(0, len(counties))))

# %%
#####
# county_id_dict

# %%
# Find counties of islands that have county level data
list_of_island_counties = (all_counties_df.county
                           .loc[all_counties_df.state
                                .isin(['American Samoa',
                                       'Guam',
                                       'Northern Mariana Islands',
                                       'Virgin Islands'])]
                                .unique())
list_of_island_counties
# Out:
# array(['Unknown', 'St. Croix', 'St. John', 'St. Thomas', 'Saipan',
#        'Tinian', 'Rota'], dtype=object)

# %%
# import fips table
fips_df = (pd.read_csv('/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/US_fips_codes.csv',
                       index_col=[0])
                .rename(columns={"FIPS":'fips','County or equivalent': 'county', 'State or equivalent': 'state'})
                .astype({'fips':'str'}))
#fips_df.info()

fips_df.county = fips_df.county.str.replace(r'\[.*?\]', '', regex=True)

# %%
# import mainland census table
census_mainland = covid_case_files[3]

df_mainland = (pd.read_csv(census_mainland, 
                          encoding='latin-1',
                          usecols=['STATE','COUNTY','STNAME','CTYNAME','ESTIMATESBASE2020'],
                          dtype={'STATE':'str','COUNTY':'str',})
                          .rename(columns={'STATE':'state_id',
                                           'COUNTY':'county_id',
                                           'STNAME':'state',
                                           'CTYNAME':'county',
                                           'ESTIMATESBASE2020':'base2020'}))

df_mainland['fips'] = (df_mainland.state_id + df_mainland.county_id).astype('int')
df_mainland = df_mainland.drop(columns=['state_id','county_id'])
df_mainland.head()
# Out:
#      state          county  base2020  fips
# 0  Alabama         Alabama   5024279  1000
# 1  Alabama  Autauga County     58805  1001
# 2  Alabama  Baldwin County    231767  1003
# 3  Alabama  Barbour County     25223  1005
# 4  Alabama     Bibb County     22293  1007

# %%
#########
df_mainland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3194 entries, 0 to 3193
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     3194 non-null   object
#  1   county    3194 non-null   object
#  2   base2020  3194 non-null   int64
#  3   fips      3194 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 99.9+ KB

# %%
##########
len(df_mainland.county.unique())
# Out:
# 1928

# %%
# Index finding tool for .at() and .loc()
def index_finder(df,column,value):
    return df.loc[df[f'{column}'] == value].index[0]

# %%
# import Samoa table
df_samoa = (pd.read_csv(covid_case_files[2],
                        encoding='latin-1', 
                        skiprows=3, 
                        header=0, 
                        usecols=['Geographic area','2020'])
            .dropna(axis=1,how='all')
            .dropna(axis=0,how='any')
            .rename(columns={'Geographic area':'county', '2020':'base2020'}))

df_samoa['state'] = 'American Samoa'
df_samoa = df_samoa.reindex(columns=['state', 'county', 'base2020'])

df_samoa.at[16,'county'] = "Swain's Island"
df_samoa.at[15,'county'] = 'Rose Atoll (Rose Island)'

#df_samoa = df_samoa.reindex(columns=['county', '2020'])
df_samoa
# Out:
#              state                    county base2020
# 1   American Samoa            American Samoa   49,710
# 3   American Samoa          Eastern District   17,059
# 4   American Samoa              Ituau county    3,431
# 5   American Samoa         Ma'oputasi county    8,568
# 6   American Samoa             Sa'ole county    1,158
# 7   American Samoa                Sua county    2,415
# 8   American Samoa           Vaifanua county    1,487
# 9   American Samoa           Manu'a District      832
# 10  American Samoa           Faleasao county      104
# 11  American Samoa            Fitiuta county      213
# 12  American Samoa                Ofu county      132
# 13  American Samoa            Olosega county      147
# 14  American Samoa               Ta'u county      236
# 15  American Samoa  Rose Atoll (Rose Island)        0
# 16  American Samoa            Swain's Island        0
# 17  American Samoa          Western District   31,819
# 18  American Samoa          Lealataua county    4,293
# 19  American Samoa            Leasina county    1,689
# 20  American Samoa           Tualatai county    3,010
# 21  American Samoa           Tualauta county   22,827

# %%
#######
# index_finder(df_samoa,'county', "Swain's Island")

df_samoa.at[index_finder(df_samoa,'county',"American Samoa"), 'base2020']
# Out:
# '49,710'

# %%
#######
fips_df.query('state == "American Samoa"')
# Out:
#       fips                    county           state
# 97   60010          Eastern District  American Samoa
# 98   60020           Manu'a District  American Samoa
# 99   60030  Rose Atoll (Rose Island)  American Samoa
# 100  60040            Swain's Island  American Samoa
# 101  60050          Western District  American Samoa

# %%
# merge Samoa and Fips
df_samoa = pd.merge(left=df_samoa, right=fips_df[['county', 'fips']], on='county', how='left')
print(len(df_samoa))


df_samoa.at[index_finder(df_samoa,'county',"American Samoa"), 'fips'] = 60000
df_samoa
# Out:
# 20
#              state                    county base2020   fips
# 0   American Samoa            American Samoa   49,710  60000
# 1   American Samoa          Eastern District   17,059  60010
# 2   American Samoa              Ituau county    3,431    NaN
# 3   American Samoa         Ma'oputasi county    8,568    NaN
# 4   American Samoa             Sa'ole county    1,158    NaN
# 5   American Samoa                Sua county    2,415    NaN
# 6   American Samoa           Vaifanua county    1,487    NaN
# 7   American Samoa           Manu'a District      832  60020
# 8   American Samoa           Faleasao county      104    NaN
# 9   American Samoa            Fitiuta county      213    NaN
# 10  American Samoa                Ofu county      132    NaN
# 11  American Samoa            Olosega county      147    NaN
# 12  American Samoa               Ta'u county      236    NaN
# 13  American Samoa  Rose Atoll (Rose Island)        0  60030
# 14  American Samoa            Swain's Island        0  60040
# 15  American Samoa          Western District   31,819  60050
# 16  American Samoa          Lealataua county    4,293    NaN
# 17  American Samoa            Leasina county    1,689    NaN
# 18  American Samoa           Tualatai county    3,010    NaN
# 19  American Samoa           Tualauta county   22,827    NaN

# %%
# Import Guam table
df_guam = (pd.read_csv(covid_case_files[5],
                       encoding='latin-1', 
                       skiprows=3, 
                       header=0, 
                       usecols=['Geographic area', '2020'])
           .dropna(axis=0,how='all')
           .dropna(axis=0,how='any')
           .rename(columns={'Geographic area':'county','2020':'base2020'}))

df_guam = df_guam.loc[df_guam['county'] != 'County subdivision not defined']
df_guam['state'] = 'Guam'
df_guam
# Out:
#                               county base2020 state
# 1                               Guam  153,836  Guam
# 3         Agana Heights municipality    3,673  Guam
# 4                  Agat municipality    4,515  Guam
# 5                  Asan municipality    2,011  Guam
# 6             Barrigada municipality    7,956  Guam
# 7     Chalan Pago-Ordot municipality    7,064  Guam
# 8                Dededo municipality   44,908  Guam
# 9             HagÃ¥tÃ±a municipality      943  Guam
# 10             Inarajan municipality    2,317  Guam
# 11             Mangilao municipality   13,476  Guam
# 12               Merizo municipality    1,604  Guam
# 13  Mongmong-Toto-Maite municipality    6,380  Guam
# 14                 Piti municipality    1,585  Guam
# 15           Santa Rita municipality    6,470  Guam
# 16             Sinajana municipality    2,611  Guam
# 17             Talofofo municipality    3,550  Guam
# 18             Tamuning municipality   18,489  Guam
# 19               Umatac municipality      647  Guam
# 20                 Yigo municipality   19,339  Guam
# 21                 Yona municipality    6,298  Guam

# %%
######
fips_df.query('state == "Guam"')
# Out:
#       fips county state
# 552  66010   Guam  Guam

# %%
# merge Guam and Fips
df_guam = pd.merge(left=df_guam, right=fips_df[['county', 'fips']], on='county', how='left')
print(len(df_guam))

df_guam
# Out:
# 20
#                               county base2020 state   fips
# 0                               Guam  153,836  Guam  66010
# 1         Agana Heights municipality    3,673  Guam    NaN
# 2                  Agat municipality    4,515  Guam    NaN
# 3                  Asan municipality    2,011  Guam    NaN
# 4             Barrigada municipality    7,956  Guam    NaN
# 5     Chalan Pago-Ordot municipality    7,064  Guam    NaN
# 6                Dededo municipality   44,908  Guam    NaN
# 7             HagÃ¥tÃ±a municipality      943  Guam    NaN
# 8              Inarajan municipality    2,317  Guam    NaN
# 9              Mangilao municipality   13,476  Guam    NaN
# 10               Merizo municipality    1,604  Guam    NaN
# 11  Mongmong-Toto-Maite municipality    6,380  Guam    NaN
# 12                 Piti municipality    1,585  Guam    NaN
# 13           Santa Rita municipality    6,470  Guam    NaN
# 14             Sinajana municipality    2,611  Guam    NaN
# 15             Talofofo municipality    3,550  Guam    NaN
# 16             Tamuning municipality   18,489  Guam    NaN
# 17               Umatac municipality      647  Guam    NaN
# 18                 Yigo municipality   19,339  Guam    NaN
# 19                 Yona municipality    6,298  Guam    NaN

# %%
# Import PR (already include fips data)
df_pr = (pd.read_csv(covid_case_files[0],
                    encoding='latin-1',
                    usecols=['STATE','COUNTY','STNAME','CNTYNAME','POPESTIMATE2020'],
                    dtype={'STATE':'str','COUNTY':'str',})
                    .rename(columns={'STATE':'state_id','COUNTY':'county_id','STNAME':'state','CNTYNAME':'county','POPESTIMATE2020':'base2020'}))

df_pr['fips'] = (df_pr.state_id + df_pr.county_id).astype('int')
df_pr = df_pr.drop(columns=['state_id','county_id'])

df_pr.head()
# Out:
#          state                  county  base2020   fips
# 0  Puerto Rico             Puerto Rico   3159343  72000
# 1  Puerto Rico      Adjuntas Municipio     17213  72001
# 2  Puerto Rico        Aguada Municipio     36343  72003
# 3  Puerto Rico     Aguadilla Municipio     49632  72005
# 4  Puerto Rico  Aguas Buenas Municipio     24598  72007

# %%
# Import VI
df_vi = (pd.read_csv(covid_case_files[12],
                     encoding='latin-1',
                     skiprows=3,
                     header=0,
                     usecols=['Geographic area','2020'])
         .dropna(axis=1, how='all')
         .dropna(axis=0, how='any')
         .rename(columns={'Geographic area':'county','2020':'base2020'}))

df_vi = df_vi.loc[df_vi['county'] != 'Island subdivision not defined']
df_vi['state'] = 'Virgin Islands'
df_vi.county = df_vi.county.str.replace(r'St\.', 'Saint', regex=True)
df_vi
# Out:
#                              county base2020           state
# 1      United States Virgin Islands   87,146  Virgin Islands
# 4                Saint Croix Island   41,004  Virgin Islands
# 5   Anna's Hope Village subdistrict    3,282  Virgin Islands
# 6         Christiansted subdistrict    1,866  Virgin Islands
# 7              East End subdistrict    2,336  Virgin Islands
# 8          Frederiksted subdistrict    2,303  Virgin Islands
# 9          Northcentral subdistrict    4,197  Virgin Islands
# 10            Northwest subdistrict    3,431  Virgin Islands
# 11            Sion Farm subdistrict   10,332  Virgin Islands
# 12         Southcentral subdistrict    7,415  Virgin Islands
# 13            Southwest subdistrict    5,842  Virgin Islands
# 15                Saint John Island    3,881  Virgin Islands
# 16              Central subdistrict      470  Virgin Islands
# 17            Coral Bay subdistrict      724  Virgin Islands
# 18             Cruz Bay subdistrict    2,652  Virgin Islands
# 19             East End subdistrict       35  Virgin Islands
# 21              Saint Thomas Island   42,261  Virgin Islands
# 22     Charlotte Amalie subdistrict   14,477  Virgin Islands
# 23             East End subdistrict    7,502  Virgin Islands
# 24            Northside subdistrict    8,889  Virgin Islands
# 25            Southside subdistrict    4,112  Virgin Islands
# 26                 Tutu subdistrict    5,129  Virgin Islands
# 27         Water Island subdistrict      164  Virgin Islands
# 28             West End subdistrict    1,988  Virgin Islands
# 32            Charlotte Amalie town    8,194  Virgin Islands
# 33        Charlotte Amalie East CDP    1,908  Virgin Islands
# 34        Charlotte Amalie West CDP    4,404  Virgin Islands
# 35               Christiansted town    1,770  Virgin Islands
# 36                    Coral Bay CDP      615  Virgin Islands
# 37                     Cruz Bay CDP    2,772  Virgin Islands
# 38                Frederiksted town      528  Virgin Islands
# 39       Frederiksted Southeast CDP    1,746  Virgin Islands
# 40                     Red Hook CDP      225  Virgin Islands
# 41                         Tutu CDP    5,519  Virgin Islands

# %%
# merge VI and Fips
df_vi = pd.merge(left=df_vi, right=fips_df[['county', 'fips']], on='county', how='left')
print(len(df_vi))

df_vi.county = df_vi.county.str.replace(r'\bSaint\b', 'St.', regex=True)
df_vi.at[index_finder(df_vi,'county', 'United States Virgin Islands'), 'fips'] = 69000
df_vi.at[index_finder(df_vi,'county', 'United States Virgin Islands'), 'county'] = 'Virgin Islands'

df_vi
# Out:
# 34
#                              county base2020           state   fips
# 0                    Virgin Islands   87,146  Virgin Islands  69000
# 1                  St. Croix Island   41,004  Virgin Islands  78010
# 2   Anna's Hope Village subdistrict    3,282  Virgin Islands    NaN
# 3         Christiansted subdistrict    1,866  Virgin Islands    NaN
# 4              East End subdistrict    2,336  Virgin Islands    NaN
# 5          Frederiksted subdistrict    2,303  Virgin Islands    NaN
# 6          Northcentral subdistrict    4,197  Virgin Islands    NaN
# 7             Northwest subdistrict    3,431  Virgin Islands    NaN
# 8             Sion Farm subdistrict   10,332  Virgin Islands    NaN
# 9          Southcentral subdistrict    7,415  Virgin Islands    NaN
# 10            Southwest subdistrict    5,842  Virgin Islands    NaN
# 11                  St. John Island    3,881  Virgin Islands  78020
# 12              Central subdistrict      470  Virgin Islands    NaN
# 13            Coral Bay subdistrict      724  Virgin Islands    NaN
# 14             Cruz Bay subdistrict    2,652  Virgin Islands    NaN
# 15             East End subdistrict       35  Virgin Islands    NaN
# 16                St. Thomas Island   42,261  Virgin Islands  78030
# 17     Charlotte Amalie subdistrict   14,477  Virgin Islands    NaN
# 18             East End subdistrict    7,502  Virgin Islands    NaN
# 19            Northside subdistrict    8,889  Virgin Islands    NaN
# 20            Southside subdistrict    4,112  Virgin Islands    NaN
# 21                 Tutu subdistrict    5,129  Virgin Islands    NaN
# 22         Water Island subdistrict      164  Virgin Islands    NaN
# 23             West End subdistrict    1,988  Virgin Islands    NaN
# 24            Charlotte Amalie town    8,194  Virgin Islands    NaN
# 25        Charlotte Amalie East CDP    1,908  Virgin Islands    NaN
# 26        Charlotte Amalie West CDP    4,404  Virgin Islands    NaN
# 27               Christiansted town    1,770  Virgin Islands    NaN
# 28                    Coral Bay CDP      615  Virgin Islands    NaN
# 29                     Cruz Bay CDP    2,772  Virgin Islands    NaN
# 30                Frederiksted town      528  Virgin Islands    NaN
# 31       Frederiksted Southeast CDP    1,746  Virgin Islands    NaN
# 32                     Red Hook CDP      225  Virgin Islands    NaN
# 33                         Tutu CDP    5,519  Virgin Islands    NaN

# %%
# Import Marianas table
df_marianas = (pd.read_csv(covid_case_files[4],
                           encoding='latin-1',
                           skiprows=4,
                           header=0,
                           usecols=['Geographic area', '2020'])
               .dropna(axis=1,how='all')
               .dropna(axis=0,how='any')
               .rename(columns={'Geographic area':'county', '2020':'base2020'}))

df_marianas = df_marianas.loc[df_marianas['county'] != 'Municipality subdivision not defined']

df_marianas['state'] = 'Northern Mariana Islands'
df_marianas
# Out:
#                                           county base2020  \
# 1   Commonwealth of the Northern Mariana Islands   47,329
# 3                  Northern Islands Municipality        7
# 4                                     District 4        7
# 6                              Rota Municipality    1,893
# 7                                     District 7    1,893
# 9                            Saipan Municipality   43,385
# 10                                    District 1   13,633
# 11                                    District 2    5,489
# 12                                    District 3   14,115
# 13                                    District 4    3,416
# 14                                    District 5    6,732
# 16                           Tinian Municipality    2,044
# 17                                    District 6    2,044
#
#                        state
# 1   Northern Mariana Islands
# 3   Northern Mariana Islands
# 4   Northern Mariana Islands
# 6   Northern Mariana Islands
# 7   Northern Mariana Islands
# 9   Northern Mariana Islands
# 10  Northern Mariana Islands
# 11  Northern Mariana Islands
# 12  Northern Mariana Islands
# 13  Northern Mariana Islands
# 14  Northern Mariana Islands
# 16  Northern Mariana Islands
# 17  Northern Mariana Islands

# %%
# merge marianas and fips
df_marianas = pd.merge(left=df_marianas, right=fips_df[['county', 'fips']], on='county', how='left')
print(len(df_marianas))

df_marianas.at[index_finder(df_marianas,'county', 'Commonwealth of the Northern Mariana Islands'), 'county'] = 'Northern Mariana Islands'
df_marianas.at[index_finder(df_marianas,'county', 'Northern Mariana Islands'), 'fips'] = 69000

df_marianas
# Out:
# 13
#                            county base2020                     state   fips
# 0        Northern Mariana Islands   47,329  Northern Mariana Islands  69000
# 1   Northern Islands Municipality        7  Northern Mariana Islands  69085
# 2                      District 4        7  Northern Mariana Islands    NaN
# 3               Rota Municipality    1,893  Northern Mariana Islands  69100
# 4                      District 7    1,893  Northern Mariana Islands    NaN
# 5             Saipan Municipality   43,385  Northern Mariana Islands  69110
# 6                      District 1   13,633  Northern Mariana Islands    NaN
# 7                      District 2    5,489  Northern Mariana Islands    NaN
# 8                      District 3   14,115  Northern Mariana Islands    NaN
# 9                      District 4    3,416  Northern Mariana Islands    NaN
# 10                     District 5    6,732  Northern Mariana Islands    NaN
# 11            Tinian Municipality    2,044  Northern Mariana Islands  69120
# 12                     District 6    2,044  Northern Mariana Islands    NaN

# %%
# build full fips table with concat
full_fips_df = pd.concat([df_mainland,df_pr,df_samoa,df_guam,df_vi,df_marianas], ignore_index=True)

# df_islands.to_csv('/Users/chriskimmons/My_Projects/NYT_COV/covidCSV/island_populations.csv')

# df_island_states = (df_islands.loc[df_islands['region']
#                              .isin(['American Samoa',
#                                     'United States Virgin Islands', 
#                                     'Commonwealth of the Northern Mariana Islands', 'Guam'])])

# df_island_states = (df_island_states[['county','base2020']]
                    

# df_island_states.base2020 = (df_island_states.base2020.replace(',','',regex=True)
#                              .astype('int'))

# df_island_states.iat[2,0] = 'Virgin Islands'
# df_island_states.iat[3,0] = 'Northern Mariana Islands'

full_fips_df.base2020 = full_fips_df.base2020.replace(',','', regex=True)
full_fips_df = (full_fips_df.dropna(axis=0, how='any')
                .astype({'base2020':'int','fips':'int'}))
full_fips_df
# Out:
#                          state                         county  base2020   fips
# 0                      Alabama                        Alabama   5024279   1000
# 1                      Alabama                 Autauga County     58805   1001
# 2                      Alabama                 Baldwin County    231767   1003
# 3                      Alabama                 Barbour County     25223   1005
# 4                      Alabama                    Bibb County     22293   1007
# ...                        ...                            ...       ...    ...
# 3347  Northern Mariana Islands       Northern Mariana Islands     47329  69000
# 3348  Northern Mariana Islands  Northern Islands Municipality         7  69085
# 3350  Northern Mariana Islands              Rota Municipality      1893  69100
# 3352  Northern Mariana Islands            Saipan Municipality     43385  69110
# 3358  Northern Mariana Islands            Tinian Municipality      2044  69120
#
# [3289 rows x 4 columns]

# %%
######
full_fips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3289 entries, 0 to 3358
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     3289 non-null   object
#  1   county    3289 non-null   object
#  2   base2020  3289 non-null   int64
#  3   fips      3289 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 128.5+ KB

# %%
#####
full_fips_df.query('fips == 51000')
# Out:
#          state    county  base2020   fips
# 2867  Virginia  Virginia   8631393  51000

# %%
# function to aggregate county populations to match NYT data
def aggregate_populations(list_of_states,list_of_counties):
    return (full_fips_df.loc[(full_fips_df.state.isin(list_of_states)) & 
                             (full_fips_df.county.isin(list_of_counties))]
                             .base2020.sum())

# find population of given state
def get_state_population(state):
    population_row =full_fips_df.loc[full_fips_df.state == state, 'base2020']
    return population_row[population_row.index[0]]

# %%
# # Fixing specific data points (New strategy)

specific_case_tuples = [
                        ('Missouri', 'Joplin Area', 0, 37592),
                        ('Missouri', 'Kansas City Area', 0, 3800)
                        ]
                    #   ('Guam','Unknown', get_state_population('Guam')),
                    #   ('American Samoa', 'Unknown', get_state_population('American Samoa')),
                    #   ('Unknown', 'Unknown', 0)]


# # aggregate regions

county_aggs = {'New_York_City_counties':['New York County', 'Kings County', 'Queens County', 'Bronx County', 'Richmond County'],
               'Valdez_Cordova_counties':['Copper River Census Area','Chugach Census Area'],
               'Bristol_Bay_and_Lake_counties':['Bristol Bay Borough','Lake and Peninsula Borough'],
               'Yakutat':['Yakutat City and Borough','Hoonah-Angoon Census Area']
               }

specific_case_tuples.extend([('New York','New York City',0, 51000),
                      ('Alaska','Valdez-Cordova Census Area', aggregate_populations(['Alaska'],county_aggs['Valdez_Cordova_counties']), 2261),
                      #('Alaska','Valdez-Cordova Census Area', 0, 2261),
                      ('Alaska', 'Bristol Bay plus Lake and Peninsula', 0, 2997),
                      ('Alaska', 'Yakutat plus Hoonah-Angoon', 0,2998)
                      ])

specific_case_tuples = pd.DataFrame(specific_case_tuples,columns=['state','county','base2020','fips'])
print(specific_case_tuples.info())

full_fips_df = pd.concat([full_fips_df,specific_case_tuples], ignore_index=True)

full_fips_df.tail(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     6 non-null      object
#  1   county    6 non-null      object
#  2   base2020  6 non-null      int64
#  3   fips      6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes
# None
#                          state                               county  base2020  \
# 3275            American Samoa                      Manu'a District       832
# 3276            American Samoa             Rose Atoll (Rose Island)         0
# 3277            American Samoa                       Swain's Island         0
# 3278            American Samoa                     Western District     31819
# 3279                      Guam                                 Guam    153836
# 3280            Virgin Islands                       Virgin Islands     87146
# 3281            Virgin Islands                     St. Croix Island     41004
# 3282            Virgin Islands                      St. John Island      3881
# 3283            Virgin Islands                    St. Thomas Island     42261
# 3284  Northern Mariana Islands             Northern Mariana Islands     47329
# 3285  Northern Mariana Islands        Northern Islands Municipality         7
# 3286  Northern Mariana Islands                    Rota Municipality      1893
# 3287  Northern Mariana Islands                  Saipan Municipality     43385
# 3288  Northern Mariana Islands                  Tinian Municipality      2044
# 3289                  Missouri                          Joplin Area         0
# 3290                  Missouri                     Kansas City Area         0
# 3291                  New York                        New York City         0
# 3292                    Alaska           Valdez-Cordova Census Area      9719
# 3293                    Alaska  Bristol Bay plus Lake and Peninsula         0
# 3294                    Alaska           Yakutat plus Hoonah-Angoon         0
#
#        fips
# 3275  60020
# 3276  60030
# 3277  60040
# 3278  60050
# 3279  66010
# 3280  69000
# 3281  78010
# 3282  78020
# 3283  78030
# 3284  69000
# 3285  69085
# 3286  69100
# 3287  69110
# 3288  69120
# 3289  37592
# 3290   3800
# 3291  51000
# 3292   2261
# 3293   2997
# 3294   2998

# %%
# separate states from counties for states table
state_pop_df = full_fips_df.query('county == state').copy()
# state_pop_df['state_id'] = state_pop_df.state.apply(lambda x: state_id_dict[x])
# state_pop_df['fips'] = state_pop_df.state.apply(lambda x: state_fips[x])
# state_popdf = state_pop_df.drop_duplicates(keep='first').reset_index(drop=True)
state_pop_df.fips = state_pop_df.fips * 0.001
state_pop_df = (state_pop_df
                .astype({'fips':'int'})
                .drop(columns=['county'])
                .drop_duplicates()
                .reset_index(drop=True))
                
state_pop_df['state_id'] = state_pop_df.index + 1
state_pop_df = state_pop_df.reindex(columns=['state_id','state','fips','base2020'])

state_pop_df
# Out:
#     state_id                     state  fips  base2020
# 0          1                   Alabama     1   5024279
# 1          2                    Alaska     2    733391
# 2          3                   Arizona     4   7151502
# 3          4                  Arkansas     5   3011524
# 4          5                California     6  39538223
# 5          6                  Colorado     8   5773714
# 6          7               Connecticut     9   3605944
# 7          8                  Delaware    10    989948
# 8          9      District of Columbia    11    689545
# 9         10                   Florida    12  21538187
# 10        11                   Georgia    13  10711908
# 11        12                    Hawaii    15   1455271
# 12        13                     Idaho    16   1839106
# 13        14                  Illinois    17  12812508
# 14        15                   Indiana    18   6785528
# 15        16                      Iowa    19   3190369
# 16        17                    Kansas    20   2937880
# 17        18                  Kentucky    21   4505836
# 18        19                 Louisiana    22   4657757
# 19        20                     Maine    23   1362359
# 20        21                  Maryland    24   6177224
# 21        22             Massachusetts    25   7029917
# 22        23                  Michigan    26  10077331
# 23        24                 Minnesota    27   5706494
# 24        25               Mississippi    28   2961279
# 25        26                  Missouri    29   6154913
# 26        27                   Montana    30   1084225
# 27        28                  Nebraska    31   1961504
# 28        29                    Nevada    32   3104614
# 29        30             New Hampshire    33   1377529
# 30        31                New Jersey    34   9288994
# 31        32                New Mexico    35   2117522
# 32        33                  New York    36  20201249
# 33        34            North Carolina    37  10439388
# 34        35              North Dakota    38    779094
# 35        36                      Ohio    39  11799448
# 36        37                  Oklahoma    40   3959353
# 37        38                    Oregon    41   4237256
# 38        39              Pennsylvania    42  13002700
# 39        40              Rhode Island    44   1097379
# 40        41            South Carolina    45   5118425
# 41        42              South Dakota    46    886667
# 42        43                 Tennessee    47   6910840
# 43        44                     Texas    48  29145505
# 44        45                      Utah    49   3271616
# 45        46                   Vermont    50    643077
# 46        47                  Virginia    51   8631393
# 47        48                Washington    53   7705281
# 48        49             West Virginia    54   1793716
# 49        50                 Wisconsin    55   5893718
# 50        51                   Wyoming    56    576851
# 51        52               Puerto Rico    72   3159343
# 52        53            American Samoa    60     49710
# 53        54                      Guam    66    153836
# 54        55            Virgin Islands    69     87146
# 55        56  Northern Mariana Islands    69     47329

# %%
######
state_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state_id  56 non-null     int64
#  1   state     56 non-null     object
#  2   fips      56 non-null     int64
#  3   base2020  56 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.9+ KB

# %%
# print State CSV
if switch:
    state_pop_df.to_csv('/Users/chriskimmons/My_Projects/NYT_COV/star_schema_files/dimState.csv', index=False)
    print('file created')
# Out:
# file created

# %% [markdown]
# County ID prep

# %%
# Separate county data

# replace_county_labels = '|'.join([' County',' county', ' Municipality', 'Municipio',' Parish'])

# county_pop_df = df_mainland.query('STNAME.astype("str") != CTYNAME.astype("str")').copy()
# county_pop_df = (county_pop_df[['STNAME','CTYNAME','ESTIMATESBASE2020']]
#                  .rename(columns={'STNAME':'state', 'CTYNAME':'county','ESTIMATESBASE2020':'base2020'})
#                  .astype({'state':'category','county':'category'}))

# county_pop_df

county_pop_df = full_fips_df.query('county != state').copy()
county_pop_df = county_pop_df.reset_index(drop=True)
print(len(county_pop_df))
# Out:
# 3238

# %%
# county_pop_df['county_id'] = county_pop_df.index + 1
# county_pop_df['state_id'] = (county_pop_df.fips * 0.001).astype('int')
# county_pop_df = county_pop_df.reindex(columns=['county_id','county','state_id','state','fips','base2020'])

# county_pop_df.head()

# %%
######
county_pop_df.tail(60)
# Out:
#                          state                               county  base2020  \
# 3178               Puerto Rico                    Isabela Municipio     40208
# 3179               Puerto Rico                     Jayuya Municipio     13711
# 3180               Puerto Rico                 Juana Díaz Municipio     44312
# 3181               Puerto Rico                     Juncos Municipio     38165
# 3182               Puerto Rico                      Lajas Municipio     21677
# 3183               Puerto Rico                      Lares Municipio     23723
# 3184               Puerto Rico                 Las Marías Municipio      7730
# 3185               Puerto Rico                Las Piedras Municipio     37043
# 3186               Puerto Rico                      Loíza Municipio     24154
# 3187               Puerto Rico                   Luquillo Municipio     17495
# 3188               Puerto Rico                     Manatí Municipio     36806
# 3189               Puerto Rico                    Maricao Municipio      5388
# 3190               Puerto Rico                    Maunabo Municipio     10228
# 3191               Puerto Rico                   Mayagüez Municipio     70259
# 3192               Puerto Rico                       Moca Municipio     34597
# 3193               Puerto Rico                    Morovis Municipio     30340
# 3194               Puerto Rico                    Naguabo Municipio     25858
# 3195               Puerto Rico                  Naranjito Municipio     27159
# 3196               Puerto Rico                   Orocovis Municipio     20038
# 3197               Puerto Rico                   Patillas Municipio     16035
# 3198               Puerto Rico                   Peñuelas Municipio     18827
# 3199               Puerto Rico                      Ponce Municipio    128858
# 3200               Puerto Rico               Quebradillas Municipio     22732
# 3201               Puerto Rico                     Rincón Municipio     13561
# 3202               Puerto Rico                 Río Grande Municipio     47762
# 3203               Puerto Rico              Sabana Grande Municipio     21455
# 3204               Puerto Rico                    Salinas Municipio     26945
# 3205               Puerto Rico                 San Germán Municipio     29796
# 3206               Puerto Rico                   San Juan Municipio    312975
# 3207               Puerto Rico                San Lorenzo Municipio     35667
# 3208               Puerto Rico              San Sebastián Municipio     34970
# 3209               Puerto Rico               Santa Isabel Municipio     21126
# 3210               Puerto Rico                   Toa Alta Municipio     72215
# 3211               Puerto Rico                   Toa Baja Municipio     73113
# 3212               Puerto Rico              Trujillo Alto Municipio     62969
# 3213               Puerto Rico                     Utuado Municipio     27014
# 3214               Puerto Rico                  Vega Alta Municipio     35863
# 3215               Puerto Rico                  Vega Baja Municipio     49342
# 3216               Puerto Rico                    Vieques Municipio      8332
# 3217               Puerto Rico                   Villalba Municipio     21082
# 3218               Puerto Rico                    Yabucoa Municipio     31916
# 3219               Puerto Rico                      Yauco Municipio     32888
# 3220            American Samoa                     Eastern District     17059
# 3221            American Samoa                      Manu'a District       832
# 3222            American Samoa             Rose Atoll (Rose Island)         0
# 3223            American Samoa                       Swain's Island         0
# 3224            American Samoa                     Western District     31819
# 3225            Virgin Islands                     St. Croix Island     41004
# 3226            Virgin Islands                      St. John Island      3881
# 3227            Virgin Islands                    St. Thomas Island     42261
# 3228  Northern Mariana Islands        Northern Islands Municipality         7
# 3229  Northern Mariana Islands                    Rota Municipality      1893
# 3230  Northern Mariana Islands                  Saipan Municipality     43385
# 3231  Northern Mariana Islands                  Tinian Municipality      2044
# 3232                  Missouri                          Joplin Area         0
# 3233                  Missouri                     Kansas City Area         0
# 3234                  New York                        New York City         0
# 3235                    Alaska           Valdez-Cordova Census Area      9719
# 3236                    Alaska  Bristol Bay plus Lake and Peninsula         0
# 3237                    Alaska           Yakutat plus Hoonah-Angoon         0
#
#        fips
# 3178  72071
# 3179  72073
# 3180  72075
# 3181  72077
# 3182  72079
# 3183  72081
# 3184  72083
# 3185  72085
# 3186  72087
# 3187  72089
# 3188  72091
# 3189  72093
# 3190  72095
# 3191  72097
# 3192  72099
# 3193  72101
# 3194  72103
# 3195  72105
# 3196  72107
# 3197  72109
# 3198  72111
# 3199  72113
# 3200  72115
# 3201  72117
# 3202  72119
# 3203  72121
# 3204  72123
# 3205  72125
# 3206  72127
# 3207  72129
# 3208  72131
# 3209  72133
# 3210  72135
# 3211  72137
# 3212  72139
# 3213  72141
# 3214  72143
# 3215  72145
# 3216  72147
# 3217  72149
# 3218  72151
# 3219  72153
# 3220  60010
# 3221  60020
# 3222  60030
# 3223  60040
# 3224  60050
# 3225  78010
# 3226  78020
# 3227  78030
# 3228  69085
# 3229  69100
# 3230  69110
# 3231  69120
# 3232  37592
# 3233   3800
# 3234  51000
# 3235   2261
# 3236   2997
# 3237   2998

# %%
#####
# pr_county_df = df_pr.query('STNAME.astype("str") != CNTYNAME.astype("str")').copy()
# pr_county_df = pr_county_df[['STNAME','CNTYNAME','POPESTIMATE2020']].rename(columns={'STNAME':'state', 'CNTYNAME':'county','POPESTIMATE2020':'base2020'})
# pr_county_df.county = pr_county_df.county.str.replace(replace_county_labels,'',regex=True)
# # pr_county_df.county = (pr_county_df.county.str.replace('á','a')
# #                        .str.replace('é','e')
# #                        .str.replace('í','i')
# #                        .str.replace('ó','o')
# #                        .str.replace('ü','u')
# #                        .str.replace('ñ','n'))
# # pr_county_df

# %%
####
# full_fips_df.region = full_fips_df.region.str.replace(replace_county_labels, '',regex=True)
# full_fips_df['2020'] = full_fips_df['2020'].replace(',','', regex=True)

# df_island_counties = full_fips_df.loc[full_fips_df.region.isin(list_of_island_counties)]
# df_island_counties = (df_island_counties[['region','2020']]
#                       .rename(columns={'region':'county','2020':'base2020'})
#                       .astype({'base2020':'int'}))
# df_island_counties['state'] = 'Northern Mariana Islands'
# df_island_counties.state[:3] = 'Virgin Islands'
# df_island_counties

# %%
####
# county_pop_df = pd.concat([county_pop_df,pr_county_df,df_island_counties],ignore_index=True)
county_pop_df.county = (county_pop_df.county.str.replace('á','a')
                       .str.replace('é','e')
                       .str.replace('í','i')
                       .str.replace('ó','o')
                       .str.replace('ü','u')
                       .str.replace('ñ','n'))

# # single cases

# %%
# check for fips of NYC counties
# full_fips_df.query('state == "New York"')

full_fips_df.loc[full_fips_df.state.isin(["New York"]) & full_fips_df.county.isin(['New York County', 'Kings County', 'Queens County', 'Bronx County', 'Richmond County'])]
# Out:
#          state           county  base2020   fips
# 1864  New York     Bronx County   1472654  36005
# 1885  New York     Kings County   2736074  36047
# 1892  New York  New York County   1694251  36061
# 1902  New York    Queens County   2405464  36081
# 1904  New York  Richmond County    495747  36085

# %%
#####
full_fips_df.query('fips == 36161')
# Out:
# Empty DataFrame
# Columns: [state, county, base2020, fips]
# Index: []

# %%
#####
county_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3238 entries, 0 to 3237
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     3238 non-null   object
#  1   county    3238 non-null   object
#  2   base2020  3238 non-null   int64
#  3   fips      3238 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 101.3+ KB

# %%
# checking Alaska counties to match fact table
alaska_fips = all_counties_df.query('state == "Alaska"').copy()
alaska_fips = alaska_fips[['county','fips']].drop_duplicates()
alaska_fips
# Out:
#                                      county  fips
# 1364                              Anchorage  2020
# 2747           Fairbanks North Star Borough  2090
# 3226              Ketchikan Gateway Borough  2130
# 3774                Kenai Peninsula Borough  2122
# 8280                Juneau City and Borough  2110
# 8283              Matanuska-Susitna Borough  2170
# 26170                               Unknown     0
# 26171             Yukon-Koyukuk Census Area  2290
# 28467       Southeast Fairbanks Census Area  2240
# 35667                    Petersburg Borough  2195
# 38150                    Bethel Census Area  2050
# 48500     Prince of Wales-Hyder Census Area  2198
# 59239                      Nome Census Area  2180
# 61956                 Kodiak Island Borough  2150
# 89750                Sitka City and Borough  2220
# 121367           Valdez-Cordova Census Area  2261
# 160341  Bristol Bay plus Lake and Peninsula  2997
# 160349             Northwest Arctic Borough  2188
# 184670                  North Slope Borough  2185
# 193850               Dillingham Census Area  2070
# 206145           Aleutians West Census Area  2016
# 218508            Wrangell City and Borough  2275
# 221581               Aleutians East Borough  2013
# 221588                       Haines Borough  2100
# 271423                       Denali Borough  2068
# 296617                 Kusilvak Census Area  2158
# 363537           Yakutat plus Hoonah-Angoon  2998
# 634972                 Skagway Municipality  2230

# %%
# # Fixing specific data points (defunct; use data blending in tableau)

specific_case_tuples = [('District of Columbia', 'District of Columbia', get_state_population('District of Columbia'), 11001)]


specific_case_tuples
# Out:
# [('District of Columbia', 'District of Columbia', 689545, 11001)]

# %%
######
# Kansas_City_agg = aggregate_populations(['Missouri'], ['Cass', 'Clay', 'Jackson', 'Platte'])
# Kansas_City_pop = 508090
# KCagg_non_urban_Population = Kansas_City_agg - Kansas_City_pop
# test_switch =county_pop_df.query('state == "Missouri"').copy()

# test_switch.loc[test_switch.county.isin(['Cass', 'Clay', 'Jackson', 'Platte']),'base2020'] = KCagg_non_urban_Population

# print(test_switch.loc[test_switch.county.isin(['Cass', 'Clay', 'Jackson', 'Platte'])],
#       '',
#       county_pop_df.loc[(county_pop_df.state == 'Missouri') & (county_pop_df.county.isin(['Cass', 'Clay', 'Jackson', 'Platte']))],
#       sep='\n')

#  use this for NYC?

# %%
#####
# Joplin_pop = 51762
# Joplin_county_agg = aggregate_populations(['Missouri'], ['Newton','Jasper'])

# print(f'County agg: {Joplin_county_agg}',
#       f'Joplin urban population: {Joplin_pop}',
#       f'County agg non urban population: {Joplin_county_agg-Joplin_pop}',
#       f'Average of nonurban county pop: {(Joplin_county_agg-Joplin_pop)/2}',
#       f'Average of urban county pop: {Joplin_pop/2}',
#       sep='\n')

# we can replace the individual counties wth the county agg non urban population
# or just don't worry about it!

# %%
####
# Newton_non= np.array([831,419,2050,12590,2230,40,47,103,620,943,204,164,66,300,356,107,623,125,166,98,286,200,]).sum()
# Jasper_non = np.array([544,193,8143,1855,15522,1495,906,134,228,2558,318,91,1406,72,1301,766,103,101,287,2159,227]).sum()

# nonJoplinpop = Newton_non + Jasper_non

# Jasper_pop = aggregate_populations(['Missouri'], ['Jasper'])
# Newton_pop = aggregate_populations(['Missouri'], ['Newton'])

# print(f'Jasper Co: {Jasper_pop}',
#       f'Jasper non Joplin: {Jasper_non}',
#       f'Japer urban?: {Jasper_pop - Jasper_non}',
#       f'Newton Co: {Newton_pop}',
#       f'Newton nonJoplin: {Newton_non}',
#       f'Newton urban?: {Newton_pop - Newton_non}',
#       f'Joplin pop: {Joplin_pop}',
#       sep='\n')

# %%
# #  add MI cities as counties (defunct)
# specific_case_tuples.extend([('Missouri','Kansas City', 508090, 38000),
#                          ('Missouri','Joplin',51762, 37592)])

# specific_case_tuples

# %%
# # add special case tuples to county data (defunct)
specific_case_tuples = pd.DataFrame(specific_case_tuples,columns=['state','county','base2020','fips'])
print(specific_case_tuples.info())

county_pop_df = pd.concat([county_pop_df,specific_case_tuples], ignore_index=True)

county_pop_df.tail(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1 non-null      object
#  1   county    1 non-null      object
#  2   base2020  1 non-null      int64
#  3   fips      1 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 160.0+ bytes
# None
#                          state                               county  base2020  \
# 3219               Puerto Rico                      Yauco Municipio     32888
# 3220            American Samoa                     Eastern District     17059
# 3221            American Samoa                      Manu'a District       832
# 3222            American Samoa             Rose Atoll (Rose Island)         0
# 3223            American Samoa                       Swain's Island         0
# 3224            American Samoa                     Western District     31819
# 3225            Virgin Islands                     St. Croix Island     41004
# 3226            Virgin Islands                      St. John Island      3881
# 3227            Virgin Islands                    St. Thomas Island     42261
# 3228  Northern Mariana Islands        Northern Islands Municipality         7
# 3229  Northern Mariana Islands                    Rota Municipality      1893
# 3230  Northern Mariana Islands                  Saipan Municipality     43385
# 3231  Northern Mariana Islands                  Tinian Municipality      2044
# 3232                  Missouri                          Joplin Area         0
# 3233                  Missouri                     Kansas City Area         0
# 3234                  New York                        New York City         0
# 3235                    Alaska           Valdez-Cordova Census Area      9719
# 3236                    Alaska  Bristol Bay plus Lake and Peninsula         0
# 3237                    Alaska           Yakutat plus Hoonah-Angoon         0
# 3238      District of Columbia                 District of Columbia    689545
#
#        fips
# 3219  72153
# 3220  60010
# 3221  60020
# 3222  60030
# 3223  60040
# 3224  60050
# 3225  78010
# 3226  78020
# 3227  78030
# 3228  69085
# 3229  69100
# 3230  69110
# 3231  69120
# 3232  37592
# 3233   3800
# 3234  51000
# 3235   2261
# 3236   2997
# 3237   2998
# 3238  11001

# %%
# Merge county df and state df to creat state_id (check here for bugs)
county_pop_df = pd.merge(county_pop_df,state_pop_df[['state_id','state']],on='state', validate='many_to_one')
county_pop_df = county_pop_df.reindex(columns=['county','state_id','state','fips','base2020'])
county_pop_df
# Out:
#                              county  state_id                     state  \
# 0                    Autauga County         1                   Alabama
# 1                    Baldwin County         1                   Alabama
# 2                    Barbour County         1                   Alabama
# 3                       Bibb County         1                   Alabama
# 4                     Blount County         1                   Alabama
# ...                             ...       ...                       ...
# 3234  Northern Islands Municipality        56  Northern Mariana Islands
# 3235              Rota Municipality        56  Northern Mariana Islands
# 3236            Saipan Municipality        56  Northern Mariana Islands
# 3237            Tinian Municipality        56  Northern Mariana Islands
# 3238           District of Columbia         9      District of Columbia
#
#        fips  base2020
# 0      1001     58805
# 1      1003    231767
# 2      1005     25223
# 3      1007     22293
# 4      1009     59134
# ...     ...       ...
# 3234  69085         7
# 3235  69100      1893
# 3236  69110     43385
# 3237  69120      2044
# 3238  11001    689545
#
# [3239 rows x 5 columns]

# %%
unknown_df = pd.DataFrame(null_states, columns=['state'])
unknown_df['county'] = 'Unknown'

unknown_df = pd.merge(left=unknown_df,right=state_pop_df,on='state')
unknown_df = unknown_df.sort_values('state_id')

# %%
county_pop_df = pd.concat([county_pop_df,unknown_df],ignore_index=True)
county_pop_df.tail(60)
# Out:
#                              county  state_id                     state  \
# 3234  Northern Islands Municipality        56  Northern Mariana Islands
# 3235              Rota Municipality        56  Northern Mariana Islands
# 3236            Saipan Municipality        56  Northern Mariana Islands
# 3237            Tinian Municipality        56  Northern Mariana Islands
# 3238           District of Columbia         9      District of Columbia
# 3239                        Unknown         1                   Alabama
# 3240                        Unknown         2                    Alaska
# 3241                        Unknown         3                   Arizona
# 3242                        Unknown         4                  Arkansas
# 3243                        Unknown         5                California
# 3244                        Unknown         6                  Colorado
# 3245                        Unknown         7               Connecticut
# 3246                        Unknown         8                  Delaware
# 3247                        Unknown        10                   Florida
# 3248                        Unknown        11                   Georgia
# 3249                        Unknown        12                    Hawaii
# 3250                        Unknown        13                     Idaho
# 3251                        Unknown        14                  Illinois
# 3252                        Unknown        15                   Indiana
# 3253                        Unknown        16                      Iowa
# 3254                        Unknown        17                    Kansas
# 3255                        Unknown        18                  Kentucky
# 3256                        Unknown        19                 Louisiana
# 3257                        Unknown        20                     Maine
# 3258                        Unknown        21                  Maryland
# 3259                        Unknown        22             Massachusetts
# 3260                        Unknown        23                  Michigan
# 3261                        Unknown        24                 Minnesota
# 3262                        Unknown        25               Mississippi
# 3263                        Unknown        26                  Missouri
# 3264                        Unknown        27                   Montana
# 3265                        Unknown        28                  Nebraska
# 3266                        Unknown        29                    Nevada
# 3267                        Unknown        30             New Hampshire
# 3268                        Unknown        31                New Jersey
# 3269                        Unknown        32                New Mexico
# 3270                        Unknown        33                  New York
# 3271                        Unknown        34            North Carolina
# 3272                        Unknown        35              North Dakota
# 3273                        Unknown        36                      Ohio
# 3274                        Unknown        37                  Oklahoma
# 3275                        Unknown        38                    Oregon
# 3276                        Unknown        39              Pennsylvania
# 3277                        Unknown        40              Rhode Island
# 3278                        Unknown        41            South Carolina
# 3279                        Unknown        42              South Dakota
# 3280                        Unknown        43                 Tennessee
# 3281                        Unknown        44                     Texas
# 3282                        Unknown        45                      Utah
# 3283                        Unknown        46                   Vermont
# 3284                        Unknown        47                  Virginia
# 3285                        Unknown        48                Washington
# 3286                        Unknown        49             West Virginia
# 3287                        Unknown        50                 Wisconsin
# 3288                        Unknown        51                   Wyoming
# 3289                        Unknown        52               Puerto Rico
# 3290                        Unknown        53            American Samoa
# 3291                        Unknown        54                      Guam
# 3292                        Unknown        55            Virgin Islands
# 3293                        Unknown        56  Northern Mariana Islands
#
#        fips  base2020
# 3234  69085         7
# 3235  69100      1893
# 3236  69110     43385
# 3237  69120      2044
# 3238  11001    689545
# 3239      1   5024279
# 3240      2    733391
# 3241      4   7151502
# 3242      5   3011524
# 3243      6  39538223
# 3244      8   5773714
# 3245      9   3605944
# 3246     10    989948
# 3247     12  21538187
# 3248     13  10711908
# 3249     15   1455271
# 3250     16   1839106
# 3251     17  12812508
# 3252     18   6785528
# 3253     19   3190369
# 3254     20   2937880
# 3255     21   4505836
# 3256     22   4657757
# 3257     23   1362359
# 3258     24   6177224
# 3259     25   7029917
# 3260     26  10077331
# 3261     27   5706494
# 3262     28   2961279
# 3263     29   6154913
# 3264     30   1084225
# 3265     31   1961504
# 3266     32   3104614
# 3267     33   1377529
# 3268     34   9288994
# 3269     35   2117522
# 3270     36  20201249
# 3271     37  10439388
# 3272     38    779094
# 3273     39  11799448
# 3274     40   3959353
# 3275     41   4237256
# 3276     42  13002700
# 3277     44   1097379
# 3278     45   5118425
# 3279     46    886667
# 3280     47   6910840
# 3281     48  29145505
# 3282     49   3271616
# 3283     50    643077
# 3284     51   8631393
# 3285     53   7705281
# 3286     54   1793716
# 3287     55   5893718
# 3288     56    576851
# 3289     72   3159343
# 3290     60     49710
# 3291     66    153836
# 3292     69     87146
# 3293     69     47329

# %%
# build county ID column
county_pop_df['county_id'] = county_pop_df.index + 1
# county_pop_df['state_id'] = (county_pop_df.fips * 0.001).astype('int')

# %%
######
county_pop_df.tail(60)
# Out:
#                              county  state_id                     state  \
# 3234  Northern Islands Municipality        56  Northern Mariana Islands
# 3235              Rota Municipality        56  Northern Mariana Islands
# 3236            Saipan Municipality        56  Northern Mariana Islands
# 3237            Tinian Municipality        56  Northern Mariana Islands
# 3238           District of Columbia         9      District of Columbia
# 3239                        Unknown         1                   Alabama
# 3240                        Unknown         2                    Alaska
# 3241                        Unknown         3                   Arizona
# 3242                        Unknown         4                  Arkansas
# 3243                        Unknown         5                California
# 3244                        Unknown         6                  Colorado
# 3245                        Unknown         7               Connecticut
# 3246                        Unknown         8                  Delaware
# 3247                        Unknown        10                   Florida
# 3248                        Unknown        11                   Georgia
# 3249                        Unknown        12                    Hawaii
# 3250                        Unknown        13                     Idaho
# 3251                        Unknown        14                  Illinois
# 3252                        Unknown        15                   Indiana
# 3253                        Unknown        16                      Iowa
# 3254                        Unknown        17                    Kansas
# 3255                        Unknown        18                  Kentucky
# 3256                        Unknown        19                 Louisiana
# 3257                        Unknown        20                     Maine
# 3258                        Unknown        21                  Maryland
# 3259                        Unknown        22             Massachusetts
# 3260                        Unknown        23                  Michigan
# 3261                        Unknown        24                 Minnesota
# 3262                        Unknown        25               Mississippi
# 3263                        Unknown        26                  Missouri
# 3264                        Unknown        27                   Montana
# 3265                        Unknown        28                  Nebraska
# 3266                        Unknown        29                    Nevada
# 3267                        Unknown        30             New Hampshire
# 3268                        Unknown        31                New Jersey
# 3269                        Unknown        32                New Mexico
# 3270                        Unknown        33                  New York
# 3271                        Unknown        34            North Carolina
# 3272                        Unknown        35              North Dakota
# 3273                        Unknown        36                      Ohio
# 3274                        Unknown        37                  Oklahoma
# 3275                        Unknown        38                    Oregon
# 3276                        Unknown        39              Pennsylvania
# 3277                        Unknown        40              Rhode Island
# 3278                        Unknown        41            South Carolina
# 3279                        Unknown        42              South Dakota
# 3280                        Unknown        43                 Tennessee
# 3281                        Unknown        44                     Texas
# 3282                        Unknown        45                      Utah
# 3283                        Unknown        46                   Vermont
# 3284                        Unknown        47                  Virginia
# 3285                        Unknown        48                Washington
# 3286                        Unknown        49             West Virginia
# 3287                        Unknown        50                 Wisconsin
# 3288                        Unknown        51                   Wyoming
# 3289                        Unknown        52               Puerto Rico
# 3290                        Unknown        53            American Samoa
# 3291                        Unknown        54                      Guam
# 3292                        Unknown        55            Virgin Islands
# 3293                        Unknown        56  Northern Mariana Islands
#
#        fips  base2020  county_id
# 3234  69085         7       3235
# 3235  69100      1893       3236
# 3236  69110     43385       3237
# 3237  69120      2044       3238
# 3238  11001    689545       3239
# 3239      1   5024279       3240
# 3240      2    733391       3241
# 3241      4   7151502       3242
# 3242      5   3011524       3243
# 3243      6  39538223       3244
# 3244      8   5773714       3245
# 3245      9   3605944       3246
# 3246     10    989948       3247
# 3247     12  21538187       3248
# 3248     13  10711908       3249
# 3249     15   1455271       3250
# 3250     16   1839106       3251
# 3251     17  12812508       3252
# 3252     18   6785528       3253
# 3253     19   3190369       3254
# 3254     20   2937880       3255
# 3255     21   4505836       3256
# 3256     22   4657757       3257
# 3257     23   1362359       3258
# 3258     24   6177224       3259
# 3259     25   7029917       3260
# 3260     26  10077331       3261
# 3261     27   5706494       3262
# 3262     28   2961279       3263
# 3263     29   6154913       3264
# 3264     30   1084225       3265
# 3265     31   1961504       3266
# 3266     32   3104614       3267
# 3267     33   1377529       3268
# 3268     34   9288994       3269
# 3269     35   2117522       3270
# 3270     36  20201249       3271
# 3271     37  10439388       3272
# 3272     38    779094       3273
# 3273     39  11799448       3274
# 3274     40   3959353       3275
# 3275     41   4237256       3276
# 3276     42  13002700       3277
# 3277     44   1097379       3278
# 3278     45   5118425       3279
# 3279     46    886667       3280
# 3280     47   6910840       3281
# 3281     48  29145505       3282
# 3282     49   3271616       3283
# 3283     50    643077       3284
# 3284     51   8631393       3285
# 3285     53   7705281       3286
# 3286     54   1793716       3287
# 3287     55   5893718       3288
# 3288     56    576851       3289
# 3289     72   3159343       3290
# 3290     60     49710       3291
# 3291     66    153836       3292
# 3292     69     87146       3293
# 3293     69     47329       3294

# %%
county_pop_df.query('county == "Kansas City Area"')
# Out:
#                 county  state_id     state  fips  base2020  county_id
# 1602  Kansas City Area        26  Missouri  3800         0       1603

# %%
######
# map state_ids to special cases

# Why Missouri?????
# county_pop_df.at[3232,'county_id'] = 0


# st_id_mapping = {'Unknown':0, 'New York':33, 'Missouri':26} 

# county_pop_df.state_id = (county_pop_df.state
#                           .map(st_id_mapping)
#                           .fillna(county_pop_df.state_id)
#                           .astype('int')) # why?

# %%
####
county_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   county     3294 non-null   object
#  1   state_id   3294 non-null   int64
#  2   state      3294 non-null   object
#  3   fips       3294 non-null   int64
#  4   base2020   3294 non-null   int64
#  5   county_id  3294 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 154.5+ KB

# %%
# sort ids to build county_id
county_pop_df = county_pop_df.sort_values('county_id').reset_index(drop=True)
county_pop_df['county_id'] = county_pop_df.index

county_pop_df.tail(15)
# Out:
#        county  state_id                     state  fips  base2020  county_id
# 3279  Unknown        42              South Dakota    46    886667       3279
# 3280  Unknown        43                 Tennessee    47   6910840       3280
# 3281  Unknown        44                     Texas    48  29145505       3281
# 3282  Unknown        45                      Utah    49   3271616       3282
# 3283  Unknown        46                   Vermont    50    643077       3283
# 3284  Unknown        47                  Virginia    51   8631393       3284
# 3285  Unknown        48                Washington    53   7705281       3285
# 3286  Unknown        49             West Virginia    54   1793716       3286
# 3287  Unknown        50                 Wisconsin    55   5893718       3287
# 3288  Unknown        51                   Wyoming    56    576851       3288
# 3289  Unknown        52               Puerto Rico    72   3159343       3289
# 3290  Unknown        53            American Samoa    60     49710       3290
# 3291  Unknown        54                      Guam    66    153836       3291
# 3292  Unknown        55            Virgin Islands    69     87146       3292
# 3293  Unknown        56  Northern Mariana Islands    69     47329       3293

# %%
#####
county_pop_df.head()
# Out:
#            county  state_id    state  fips  base2020  county_id
# 0  Autauga County         1  Alabama  1001     58805          0
# 1  Baldwin County         1  Alabama  1003    231767          1
# 2  Barbour County         1  Alabama  1005     25223          2
# 3     Bibb County         1  Alabama  1007     22293          3
# 4   Blount County         1  Alabama  1009     59134          4

# %%
#####
county_pop_df.query('county == "Unknown"')
# Out:
#        county  state_id                     state  fips  base2020  county_id
# 3239  Unknown         1                   Alabama     1   5024279       3239
# 3240  Unknown         2                    Alaska     2    733391       3240
# 3241  Unknown         3                   Arizona     4   7151502       3241
# 3242  Unknown         4                  Arkansas     5   3011524       3242
# 3243  Unknown         5                California     6  39538223       3243
# 3244  Unknown         6                  Colorado     8   5773714       3244
# 3245  Unknown         7               Connecticut     9   3605944       3245
# 3246  Unknown         8                  Delaware    10    989948       3246
# 3247  Unknown        10                   Florida    12  21538187       3247
# 3248  Unknown        11                   Georgia    13  10711908       3248
# 3249  Unknown        12                    Hawaii    15   1455271       3249
# 3250  Unknown        13                     Idaho    16   1839106       3250
# 3251  Unknown        14                  Illinois    17  12812508       3251
# 3252  Unknown        15                   Indiana    18   6785528       3252
# 3253  Unknown        16                      Iowa    19   3190369       3253
# 3254  Unknown        17                    Kansas    20   2937880       3254
# 3255  Unknown        18                  Kentucky    21   4505836       3255
# 3256  Unknown        19                 Louisiana    22   4657757       3256
# 3257  Unknown        20                     Maine    23   1362359       3257
# 3258  Unknown        21                  Maryland    24   6177224       3258
# 3259  Unknown        22             Massachusetts    25   7029917       3259
# 3260  Unknown        23                  Michigan    26  10077331       3260
# 3261  Unknown        24                 Minnesota    27   5706494       3261
# 3262  Unknown        25               Mississippi    28   2961279       3262
# 3263  Unknown        26                  Missouri    29   6154913       3263
# 3264  Unknown        27                   Montana    30   1084225       3264
# 3265  Unknown        28                  Nebraska    31   1961504       3265
# 3266  Unknown        29                    Nevada    32   3104614       3266
# 3267  Unknown        30             New Hampshire    33   1377529       3267
# 3268  Unknown        31                New Jersey    34   9288994       3268
# 3269  Unknown        32                New Mexico    35   2117522       3269
# 3270  Unknown        33                  New York    36  20201249       3270
# 3271  Unknown        34            North Carolina    37  10439388       3271
# 3272  Unknown        35              North Dakota    38    779094       3272
# 3273  Unknown        36                      Ohio    39  11799448       3273
# 3274  Unknown        37                  Oklahoma    40   3959353       3274
# 3275  Unknown        38                    Oregon    41   4237256       3275
# 3276  Unknown        39              Pennsylvania    42  13002700       3276
# 3277  Unknown        40              Rhode Island    44   1097379       3277
# 3278  Unknown        41            South Carolina    45   5118425       3278
# 3279  Unknown        42              South Dakota    46    886667       3279
# 3280  Unknown        43                 Tennessee    47   6910840       3280
# 3281  Unknown        44                     Texas    48  29145505       3281
# 3282  Unknown        45                      Utah    49   3271616       3282
# 3283  Unknown        46                   Vermont    50    643077       3283
# 3284  Unknown        47                  Virginia    51   8631393       3284
# 3285  Unknown        48                Washington    53   7705281       3285
# 3286  Unknown        49             West Virginia    54   1793716       3286
# 3287  Unknown        50                 Wisconsin    55   5893718       3287
# 3288  Unknown        51                   Wyoming    56    576851       3288
# 3289  Unknown        52               Puerto Rico    72   3159343       3289
# 3290  Unknown        53            American Samoa    60     49710       3290
# 3291  Unknown        54                      Guam    66    153836       3291
# 3292  Unknown        55            Virgin Islands    69     87146       3292
# 3293  Unknown        56  Northern Mariana Islands    69     47329       3293

# %%
#####
# diamond_princess = 3711
# grand_princess =  3533

all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3525161 entries, 0 to 3525160
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   fips    int64
#  4   cases   int64
#  5   deaths  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 161.4+ MB

# %%
# finally, we clean the 'Pending County Assignment'
all_counties_df = all_counties_df.drop(all_counties_df[all_counties_df.county=='Pending County Assignment'].index)

all_counties_df[all_counties_df.county=='Pending County Assignment']
# Out:
# Empty DataFrame
# Columns: [date, state, county, fips, cases, deaths]
# Index: []

# %%
# fill unknown county with state name (HERE!!!!)
# all_counties_df.county = np.where(all_counties_df.state.isin(['Guam','American Samoa']), all_counties_df.state, all_counties_df.county)

# %%
# # maps fips codes to places missing fips data
# # all_counties_df.fips = np.where(all_counties_df.state == 'Guam', 66, all_counties_df.fips)
# # all_counties_df.fips = np.where(all_counties_df.state == 'American Samoa', 60, all_counties_df.fips)

# fips_mapping = {'Unknown':0, 'Joplin Area': 37592, 'Kansas City Area':38000, 'New York City':51000}

# all_counties_df.fips = (all_counties_df.county
#                         .map(fips_mapping)
#                         .fillna(all_counties_df.fips)
#                         .astype('int'))

# # move this to the top

# %%
# # Check for NYC rows
# all_counties_df.query('county == "New York City"')

# %%
# # check for Nyc county cells
# all_counties_df.query('county == "Bronx"')

# %%
#####
# test_eqivalent_series_union = pd.Series(np.union1d(all_counties_df.county, county_pop_df.county)).copy()
# test_eqivalent_series_intersect = pd.Series(np.intersect1d(all_counties_df.county, county_pop_df.county)).copy()
# leftovers = test_eqivalent_series_union[~test_eqivalent_series_union.isin(test_eqivalent_series_intersect)].reset_index()
# leftovers

all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3525071 entries, 0 to 3525160
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   fips    int64
#  4   cases   int64
#  5   deaths  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 188.3+ MB

# %% [markdown]
# Make County Dict

# %%
######
# counties = list(county_pop_df.county.unique())
# counties.sort()
# unknown = counties.index('Unknown')
# unknown = counties.pop(unknown)
# counties.insert(0, unknown)
# counties

# %%
# make dict
# county_id_dict = dict(zip(counties, np.arange(0, len(counties))))

# %%
#####
# county_id_dict['District of Columbia']

# %%
#####
county_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   county     3294 non-null   object
#  1   state_id   3294 non-null   int64
#  2   state      3294 non-null   object
#  3   fips       3294 non-null   int64
#  4   base2020   3294 non-null   int64
#  5   county_id  3294 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 154.5+ KB

# %%
#####
# county_pop_df['county_id'] = county_pop_df.county.apply(lambda x: county_id_dict[x])
# county_pop_df['county_id'] = county_pop_df.index + 1
# county_pop_df['state_id'] = county_pop_df.state.apply(lambda x: state_id_dict[x])
# county_pop_df['fips'] = county_pop_df.county.apply(lambda x: county_fips[x])

# %%
######
county_pop_df.query('county == "District of Columbia"')
# Out:
#                     county  state_id                 state   fips  base2020  \
# 3238  District of Columbia         9  District of Columbia  11001    689545
#
#       county_id
# 3238       3238

# %%
########
# county_id_dict2 = {x:y for x,y in zip(county_pop_df.county, county_pop_df.county_id)}
# print(len(county_id_dict2))
# county_id_dict2

# %%
######
county_pop_df.loc[county_pop_df.state == 'American Samoa']
# Out:
#                         county  state_id           state   fips  base2020  \
# 3226          Eastern District        53  American Samoa  60010     17059
# 3227           Manu'a District        53  American Samoa  60020       832
# 3228  Rose Atoll (Rose Island)        53  American Samoa  60030         0
# 3229            Swain's Island        53  American Samoa  60040         0
# 3230          Western District        53  American Samoa  60050     31819
# 3290                   Unknown        53  American Samoa     60     49710
#
#       county_id
# 3226       3226
# 3227       3227
# 3228       3228
# 3229       3229
# 3230       3230
# 3290       3290

# %%
######
print(county_pop_df.head(),
      '',
      county_pop_df.tail(),
      sep='\n')
# Out:
#            county  state_id    state  fips  base2020  county_id
# 0  Autauga County         1  Alabama  1001     58805          0
# 1  Baldwin County         1  Alabama  1003    231767          1
# 2  Barbour County         1  Alabama  1005     25223          2
# 3     Bibb County         1  Alabama  1007     22293          3
# 4   Blount County         1  Alabama  1009     59134          4
#
#        county  state_id                     state  fips  base2020  county_id
# 3289  Unknown        52               Puerto Rico    72   3159343       3289
# 3290  Unknown        53            American Samoa    60     49710       3290
# 3291  Unknown        54                      Guam    66    153836       3291
# 3292  Unknown        55            Virgin Islands    69     87146       3292
# 3293  Unknown        56  Northern Mariana Islands    69     47329       3293

# %%
# remove extra language from counties, reset where appropriate
replace_county_labels = '|'.join([' County',' Municipality',' Island',' Municipio',' Parish'])
county_pop_df.county = county_pop_df.county.str.replace(replace_county_labels,'',regex=True, case=False)

county_pop_df.county.loc[county_pop_df.county == 'Dona Ana'] = 'Doña Ana'

county_pop_df.county.loc[county_pop_df.county == 'Skagway'] = 'Skagway Municipality'

county_pop_df.county.loc[county_pop_df.county == 'Kodiak Borough'] = 'Kodiak Island Borough'

county_pop_df.county.loc[(county_pop_df.county == 'Rock') & (county_pop_df.state == 'Illinois')] = 'Rock Island'
# Out:
# /var/folders/0l/761g3tyj37z09qmvp8fym23w0000gn/T/ipykernel_36545/67936573.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_pop_df.county.loc[county_pop_df.county == 'Dona Ana'] = 'Doña Ana'
# /var/folders/0l/761g3tyj37z09qmvp8fym23w0000gn/T/ipykernel_36545/67936573.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_pop_df.county.loc[county_pop_df.county == 'Skagway'] = 'Skagway Municipality'
# /var/folders/0l/761g3tyj37z09qmvp8fym23w0000gn/T/ipykernel_36545/67936573.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_pop_df.county.loc[county_pop_df.county == 'Kodiak Borough'] = 'Kodiak Island Borough'
# /var/folders/0l/761g3tyj37z09qmvp8fym23w0000gn/T/ipykernel_36545/67936573.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_pop_df.county.loc[(county_pop_df.county == 'Rock') & (county_pop_df.state == 'Illinois')] = 'Rock Island'

# %%
######
county_pop_df.query('county == "Joplin Area"')
# Out:
#            county  state_id     state   fips  base2020  county_id
# 1601  Joplin Area        26  Missouri  37592         0       1601

# %%
# creat county CSV
if switch:
    county_pop_df.to_csv('/Users/chriskimmons/My_Projects/NYT_COV/star_schema_files/dimCounty.csv',index=False)
    print('file created')
# Out:
# file created

# %% [markdown]
# Create Date table

# %%
# find unque dates
unique_dates = pd.Series(all_counties_df.date.unique())
unique_dates
# Out:
# 0      2020-01-21
# 1      2020-01-22
# 2      2020-01-23
# 3      2020-01-24
# 4      2020-01-25
#           ...
# 1153   2023-03-19
# 1154   2023-03-20
# 1155   2023-03-21
# 1156   2023-03-22
# 1157   2023-03-23
# Length: 1158, dtype: datetime64[ns]

# %%
# create date df
date_table = pd.DataFrame(columns=['date_id', 'full_date','year','quarter','quarter_name','month','month_name','day','day_of_week','day_of_year'])

# %%
# fill columns

date_table.date_id = unique_dates.index + 1
date_table.full_date = unique_dates
date_table.year = unique_dates.dt.year
date_table.quarter = unique_dates.dt.quarter
date_table.quarter_name = 'Q'+ unique_dates.dt.quarter.astype(str)
date_table.month = unique_dates.dt.month
date_table.month_name = unique_dates.dt.month_name()
date_table.day = unique_dates.dt.day
date_table.day_of_week = unique_dates.dt.day_of_week
date_table.day_of_year = unique_dates.dt.day_of_year

# %%
####
date_table.head()
# Out:
#    date_id  full_date  year  quarter quarter_name  month month_name  day  \
# 0        1 2020-01-21  2020        1           Q1      1    January   21
# 1        2 2020-01-22  2020        1           Q1      1    January   22
# 2        3 2020-01-23  2020        1           Q1      1    January   23
# 3        4 2020-01-24  2020        1           Q1      1    January   24
# 4        5 2020-01-25  2020        1           Q1      1    January   25
#
#    day_of_week  day_of_year
# 0            1           21
# 1            2           22
# 2            3           23
# 3            4           24
# 4            5           25

# %%
####
date_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_id       1158 non-null   int64
#  1   full_date     1158 non-null   datetime64[ns]
#  2   year          1158 non-null   int64
#  3   quarter       1158 non-null   int64
#  4   quarter_name  1158 non-null   object
#  5   month         1158 non-null   int64
#  6   month_name    1158 non-null   object
#  7   day           1158 non-null   int64
#  8   day_of_week   1158 non-null   int64
#  9   day_of_year   1158 non-null   int64
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 90.6+ KB

# %%
####
date_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158 entries, 0 to 1157
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_id       1158 non-null   int64
#  1   full_date     1158 non-null   datetime64[ns]
#  2   year          1158 non-null   int64
#  3   quarter       1158 non-null   int64
#  4   quarter_name  1158 non-null   object
#  5   month         1158 non-null   int64
#  6   month_name    1158 non-null   object
#  7   day           1158 non-null   int64
#  8   day_of_week   1158 non-null   int64
#  9   day_of_year   1158 non-null   int64
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 90.6+ KB

# %%
####
all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3525071 entries, 0 to 3525160
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   fips    int64
#  4   cases   int64
#  5   deaths  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 188.3+ MB

# %%
#####
# date_dict = {date_table.full_date:date_table.date_id}
# date_dict = dict(zip(date_table.full_date, np.arange(0,len(date_table.full_date))))

# %%
#####
date_table.head(10)
# Out:
#    date_id  full_date  year  quarter quarter_name  month month_name  day  \
# 0        1 2020-01-21  2020        1           Q1      1    January   21
# 1        2 2020-01-22  2020        1           Q1      1    January   22
# 2        3 2020-01-23  2020        1           Q1      1    January   23
# 3        4 2020-01-24  2020        1           Q1      1    January   24
# 4        5 2020-01-25  2020        1           Q1      1    January   25
# 5        6 2020-01-26  2020        1           Q1      1    January   26
# 6        7 2020-01-27  2020        1           Q1      1    January   27
# 7        8 2020-01-28  2020        1           Q1      1    January   28
# 8        9 2020-01-29  2020        1           Q1      1    January   29
# 9       10 2020-01-30  2020        1           Q1      1    January   30
#
#    day_of_week  day_of_year
# 0            1           21
# 1            2           22
# 2            3           23
# 3            4           24
# 4            5           25
# 5            6           26
# 6            0           27
# 7            1           28
# 8            2           29
# 9            3           30

# %%
# create date CSV
if switch:
    date_table.to_csv('/Users/chriskimmons/My_Projects/NYT_COV/star_schema_files/dimDate.csv', index=False)
    print('file created')
# Out:
# file created

# %% [markdown]
# Fact table

# %%
# all_counties_df = all_counties_df.drop(columns=['fips'])

# all_counties_df = all_counties_df.merge(county_pop_df[['state','county','fips']],on=['state','county'],how='left').astype({'fips':'int'})

# %%
# aggregate Kansas city MI and Joplin MI

def city_aggregator(df,
                    state,
                    list_of_counties,
                    aggregated_region_name, 
                    fips=0):
    
    filtered_counties = df.loc[(df.state == f'{state}') & 
                               (df.county.isin(list_of_counties))]
    counties_aggregated = (filtered_counties
                           .groupby('date')
                           .sum())
    counties_aggregated['fips'] = fips
    counties_aggregated['county'] = aggregated_region_name
    counties_aggregated['state'] = state

    counties_aggregated = counties_aggregated.reset_index()
    df  = (pd.concat([df,
                      counties_aggregated],
                     ignore_index=True)
           .sort_values('date')
           .reset_index(drop=True))
    filtered_counties = df.loc[(df.state == f'{state}') & 
                               (df.county.isin(list_of_counties))]
    
    df = df.drop(filtered_counties.index)
    # print(df.loc[filtered_counties.index])
    return df

# %%
all_counties_df = city_aggregator(all_counties_df,
                                  'Missouri',
                                  ['Jasper','Newton','Joplin'],
                                   'Joplin Area',
                                   fips=37592)

print(all_counties_df.query('county == "Joplin Area"').head(1),
      " ",
      all_counties_df.query('county == "Jasper" & state == "Missouri"').head(1),
      sep='\n')
# Out:
#            date     state       county   fips  cases  deaths
# 6432 2020-03-21  Missouri  Joplin Area  37592      1       0
#
# Empty DataFrame
# Columns: [date, state, county, fips, cases, deaths]
# Index: []

# %%
all_counties_df = city_aggregator(all_counties_df,
                                  'Missouri',
                                  ['Cass','Clay','Platte','Jackson','Kansas City'],
                                   'Kansas City Area',
                                   fips=38000)

print(all_counties_df.query('county == "Kansas City Area"').head(1),
      " ",
      all_counties_df.query('county == "Cass" & state == "Missouri"').head(1),
      sep='\n')
# Out:
#            date     state            county   fips  cases  deaths
# 2887 2020-03-16  Missouri  Kansas City Area  38000      1       0
#
# Empty DataFrame
# Columns: [date, state, county, fips, cases, deaths]
# Index: []

# %%
all_counties_df = all_counties_df.drop(columns=['fips'])

all_counties_df = all_counties_df.merge(county_pop_df[['state','county','fips']],on=['state','county'],how='left')

# %%
all_counties_df.query('county == "New York City"')
# Out:
#               date     state         county    cases  deaths   fips
# 416     2020-03-01  New York  New York City        1       0  51000
# 444     2020-03-02  New York  New York City        1       0  51000
# 482     2020-03-03  New York  New York City        2       0  51000
# 523     2020-03-04  New York  New York City        2       0  51000
# 561     2020-03-05  New York  New York City        4       0  51000
# ...            ...       ...            ...      ...     ...    ...
# 3502630 2023-03-19  New York  New York City  3250654   45008  51000
# 3505883 2023-03-20  New York  New York City  3250980   45008  51000
# 3509168 2023-03-21  New York  New York City  3252151   45005  51000
# 3512379 2023-03-22  New York  New York City  3252357   45155  51000
# 3515717 2023-03-23  New York  New York City  3252967   45123  51000
#
# [1118 rows x 6 columns]

# %%
# fips_mapping = {'Joplin Area': 37592, 'Kansas City Area':38000, 'New York City':51000, 'District of Columbia':11001}

# all_counties_df.fips = (all_counties_df.county
#                         .map(fips_mapping)
#                         .fillna(all_counties_df.fips)
#                         )

# %%
all_counties_df.loc[all_counties_df.fips.isna()]
# Out:
# Empty DataFrame
# Columns: [date, state, county, cases, deaths, fips]
# Index: []

# %%
all_counties_df.query('county == "Unknown"').sort_values(by='fips')
# Out:
#               date        state   county  cases  deaths  fips
# 2913731 2022-09-18      Alabama  Unknown   1025       3     1
# 2988212 2022-10-11      Alabama  Unknown   2101      16     1
# 3011195 2022-10-18      Alabama  Unknown   1672      17     1
# 3255317 2023-01-01      Alabama  Unknown   4703       0     1
# 2955950 2022-10-01      Alabama  Unknown    744       1     1
# ...            ...          ...      ...    ...     ...   ...
# 88707   2020-04-25  Puerto Rico  Unknown   1307      83    72
# 1358102 2021-05-27  Puerto Rico  Unknown   5568    2489    72
# 830228  2020-12-15  Puerto Rico  Unknown   3274    1294    72
# 823750  2020-12-13  Puerto Rico  Unknown   3245    1272    72
# 2292211 2022-03-11  Puerto Rico  Unknown  16786    4148    72
#
# [31937 rows x 6 columns]

# %%
# copy table from all counties
fact_table = all_counties_df.copy()

# %%
####
all_counties_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3518584 entries, 0 to 3518583
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   state   object
#  2   county  object
#  3   cases   int64
#  4   deaths  int64
#  5   fips    int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 187.9+ MB

# %%
####
county_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   county     3294 non-null   object
#  1   state_id   3294 non-null   int64
#  2   state      3294 non-null   object
#  3   fips       3294 non-null   int64
#  4   base2020   3294 non-null   int64
#  5   county_id  3294 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 154.5+ KB

# %%
fact_table.query('county == "Unknown"')
# Out:
#               date         state   county  cases  deaths  fips
# 411     2020-03-01  Rhode Island  Unknown      2       0    44
# 442     2020-03-02  Rhode Island  Unknown      2       0    44
# 492     2020-03-03  Rhode Island  Unknown      2       0    44
# 521     2020-03-04  Rhode Island  Unknown      2       0    44
# 568     2020-03-05  Rhode Island  Unknown      2       0    44
# ...            ...           ...      ...    ...     ...   ...
# 3518046 2023-03-23        Hawaii  Unknown      0      77    15
# 3518055 2023-03-23          Guam  Unknown  62077     416    66
# 3518182 2023-03-23      Illinois  Unknown      0    2796    17
# 3518208 2023-03-23       Indiana  Unknown      1     162    18
# 3518442 2023-03-23          Iowa  Unknown      1       0    19
#
# [31937 rows x 6 columns]

# %%
county_pop_df.query('county == "Unknown"')
# Out:
#        county  state_id                     state  fips  base2020  county_id
# 3239  Unknown         1                   Alabama     1   5024279       3239
# 3240  Unknown         2                    Alaska     2    733391       3240
# 3241  Unknown         3                   Arizona     4   7151502       3241
# 3242  Unknown         4                  Arkansas     5   3011524       3242
# 3243  Unknown         5                California     6  39538223       3243
# 3244  Unknown         6                  Colorado     8   5773714       3244
# 3245  Unknown         7               Connecticut     9   3605944       3245
# 3246  Unknown         8                  Delaware    10    989948       3246
# 3247  Unknown        10                   Florida    12  21538187       3247
# 3248  Unknown        11                   Georgia    13  10711908       3248
# 3249  Unknown        12                    Hawaii    15   1455271       3249
# 3250  Unknown        13                     Idaho    16   1839106       3250
# 3251  Unknown        14                  Illinois    17  12812508       3251
# 3252  Unknown        15                   Indiana    18   6785528       3252
# 3253  Unknown        16                      Iowa    19   3190369       3253
# 3254  Unknown        17                    Kansas    20   2937880       3254
# 3255  Unknown        18                  Kentucky    21   4505836       3255
# 3256  Unknown        19                 Louisiana    22   4657757       3256
# 3257  Unknown        20                     Maine    23   1362359       3257
# 3258  Unknown        21                  Maryland    24   6177224       3258
# 3259  Unknown        22             Massachusetts    25   7029917       3259
# 3260  Unknown        23                  Michigan    26  10077331       3260
# 3261  Unknown        24                 Minnesota    27   5706494       3261
# 3262  Unknown        25               Mississippi    28   2961279       3262
# 3263  Unknown        26                  Missouri    29   6154913       3263
# 3264  Unknown        27                   Montana    30   1084225       3264
# 3265  Unknown        28                  Nebraska    31   1961504       3265
# 3266  Unknown        29                    Nevada    32   3104614       3266
# 3267  Unknown        30             New Hampshire    33   1377529       3267
# 3268  Unknown        31                New Jersey    34   9288994       3268
# 3269  Unknown        32                New Mexico    35   2117522       3269
# 3270  Unknown        33                  New York    36  20201249       3270
# 3271  Unknown        34            North Carolina    37  10439388       3271
# 3272  Unknown        35              North Dakota    38    779094       3272
# 3273  Unknown        36                      Ohio    39  11799448       3273
# 3274  Unknown        37                  Oklahoma    40   3959353       3274
# 3275  Unknown        38                    Oregon    41   4237256       3275
# 3276  Unknown        39              Pennsylvania    42  13002700       3276
# 3277  Unknown        40              Rhode Island    44   1097379       3277
# 3278  Unknown        41            South Carolina    45   5118425       3278
# 3279  Unknown        42              South Dakota    46    886667       3279
# 3280  Unknown        43                 Tennessee    47   6910840       3280
# 3281  Unknown        44                     Texas    48  29145505       3281
# 3282  Unknown        45                      Utah    49   3271616       3282
# 3283  Unknown        46                   Vermont    50    643077       3283
# 3284  Unknown        47                  Virginia    51   8631393       3284
# 3285  Unknown        48                Washington    53   7705281       3285
# 3286  Unknown        49             West Virginia    54   1793716       3286
# 3287  Unknown        50                 Wisconsin    55   5893718       3287
# 3288  Unknown        51                   Wyoming    56    576851       3288
# 3289  Unknown        52               Puerto Rico    72   3159343       3289
# 3290  Unknown        53            American Samoa    60     49710       3290
# 3291  Unknown        54                      Guam    66    153836       3291
# 3292  Unknown        55            Virgin Islands    69     87146       3292
# 3293  Unknown        56  Northern Mariana Islands    69     47329       3293

# %%
fact_table.query('county == "Kansas City Area"')
# Out:
#               date     state            county   cases  deaths  fips
# 2887    2020-03-16  Missouri  Kansas City Area       1       0  3800
# 3386    2020-03-17  Missouri  Kansas City Area       4       0  3800
# 3974    2020-03-18  Missouri  Kansas City Area       5       0  3800
# 4655    2020-03-19  Missouri  Kansas City Area       7       0  3800
# 5472    2020-03-20  Missouri  Kansas City Area      23       1  3800
# ...            ...       ...               ...     ...     ...   ...
# 3503040 2023-03-19  Missouri  Kansas City Area  335124    4453  3800
# 3506288 2023-03-20  Missouri  Kansas City Area  335124    4453  3800
# 3509537 2023-03-21  Missouri  Kansas City Area  335497    4455  3800
# 3512786 2023-03-22  Missouri  Kansas City Area  335497    4455  3800
# 3518583 2023-03-23  Missouri  Kansas City Area  335497    4455  3800
#
# [1103 rows x 6 columns]

# %%
county_pop_df.query('county == "Kansas City Area"')
# Out:
#                 county  state_id     state  fips  base2020  county_id
# 1602  Kansas City Area        26  Missouri  3800         0       1602

# %%
# merge with fips table (look here for bugs)

# fact_table['date_id'] = fact_table.date.apply(lambda x: date_dict[x])
# fact_table['county_id'] = fact_table.county.apply(lambda x,y: county_id_dict[x] & )
# fact_table['state_id'] = fact_table.state.apply(lambda x: state_id_dict[x])

# fact_table = pd.merge(left=fact_table, right=county_pop_df[['fips','state_id','county_id']], on='fips')

# fact_table = fact_table.merge(left_on=fact_table,right_on=date_table[['full_date','date_id']], on=)

fact_table = (fact_table
              .merge(county_pop_df[['fips','state_id','county_id']],left_on='fips',right_on='fips', how='left')
              .merge(date_table[['full_date','date_id']],left_on='date',right_on='full_date')
              )

fact_table['case_id'] = fact_table.index + 1

# %%
# fact_table = fact_table.astype({'state_id':'int', 'county_id':'int'})

fact_table.loc[fact_table.state_id.isnull()].county.unique()
# Out:
# array([], dtype=object)

# %%
county_pop_df.query('county == "Kansas City Area"')
# Out:
#                 county  state_id     state  fips  base2020  county_id
# 1602  Kansas City Area        26  Missouri  3800         0       1602

# %%
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3519450 entries, 0 to 3519449
# Data columns (total 11 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   date       datetime64[ns]
#  1   state      object
#  2   county     object
#  3   cases      int64
#  4   deaths     int64
#  5   fips       int64
#  6   state_id   int64
#  7   county_id  int64
#  8   full_date  datetime64[ns]
#  9   date_id    int64
#  10  case_id    int64
# dtypes: datetime64[ns](2), int64(7), object(2)
# memory usage: 322.2+ MB

# %%
fact_table.query('county == "District of Columbia"')
# Out:
#               date                 state                county   cases  \
# 684     2020-03-07  District of Columbia  District of Columbia       1
# 777     2020-03-08  District of Columbia  District of Columbia       1
# 896     2020-03-09  District of Columbia  District of Columbia       4
# 1030    2020-03-10  District of Columbia  District of Columbia       4
# 1197    2020-03-11  District of Columbia  District of Columbia      10
# ...            ...                   ...                   ...     ...
# 3505683 2023-03-19  District of Columbia  District of Columbia  178106
# 3508929 2023-03-20  District of Columbia  District of Columbia  178106
# 3512175 2023-03-21  District of Columbia  District of Columbia  178106
# 3515892 2023-03-22  District of Columbia  District of Columbia  178106
# 3518674 2023-03-23  District of Columbia  District of Columbia  178226
#
#          deaths   fips  state_id  county_id  full_date  date_id  case_id
# 684           0  11001         9       3238 2020-03-07       47      685
# 777           0  11001         9       3238 2020-03-08       48      778
# 896           0  11001         9       3238 2020-03-09       49      897
# 1030          0  11001         9       3238 2020-03-10       50     1031
# 1197          0  11001         9       3238 2020-03-11       51     1198
# ...         ...    ...       ...        ...        ...      ...      ...
# 3505683    1432  11001         9       3238 2023-03-19     1154  3505684
# 3508929    1432  11001         9       3238 2023-03-20     1155  3508930
# 3512175    1432  11001         9       3238 2023-03-21     1156  3512176
# 3515892    1432  11001         9       3238 2023-03-22     1157  3515893
# 3518674    1432  11001         9       3238 2023-03-23     1158  3518675
#
# [1112 rows x 11 columns]

# %%
fact_table.loc[fact_table.county_id.isna()].county.unique()
# Out:
# array([], dtype=object)

# %%
####
fact_table.head(60)
# Out:
#          date          state         county  cases  deaths   fips  state_id  \
# 0  2020-01-21     Washington      Snohomish      1       0  53061        48
# 1  2020-01-22     Washington      Snohomish      1       0  53061        48
# 2  2020-01-23     Washington      Snohomish      1       0  53061        48
# 3  2020-01-24       Illinois           Cook      1       0  17031        14
# 4  2020-01-24     Washington      Snohomish      1       0  53061        48
# 5  2020-01-25     California         Orange      1       0   6059         5
# 6  2020-01-25       Illinois           Cook      1       0  17031        14
# 7  2020-01-25     Washington      Snohomish      1       0  53061        48
# 8  2020-01-26        Arizona       Maricopa      1       0   4013         3
# 9  2020-01-26     California    Los Angeles      1       0   6037         5
# 10 2020-01-26     California         Orange      1       0   6059         5
# 11 2020-01-26       Illinois           Cook      1       0  17031        14
# 12 2020-01-26     Washington      Snohomish      1       0  53061        48
# 13 2020-01-27     California         Orange      1       0   6059         5
# 14 2020-01-27        Arizona       Maricopa      1       0   4013         3
# 15 2020-01-27       Illinois           Cook      1       0  17031        14
# 16 2020-01-27     Washington      Snohomish      1       0  53061        48
# 17 2020-01-27     California    Los Angeles      1       0   6037         5
# 18 2020-01-28        Arizona       Maricopa      1       0   4013         3
# 19 2020-01-28     California    Los Angeles      1       0   6037         5
# 20 2020-01-28     California         Orange      1       0   6059         5
# 21 2020-01-28       Illinois           Cook      1       0  17031        14
# 22 2020-01-28     Washington      Snohomish      1       0  53061        48
# 23 2020-01-29        Arizona       Maricopa      1       0   4013         3
# 24 2020-01-29     California    Los Angeles      1       0   6037         5
# 25 2020-01-29     California         Orange      1       0   6059         5
# 26 2020-01-29       Illinois           Cook      1       0  17031        14
# 27 2020-01-29     Washington      Snohomish      1       0  53061        48
# 28 2020-01-30     California         Orange      1       0   6059         5
# 29 2020-01-30     California    Los Angeles      1       0   6037         5
# 30 2020-01-30     Washington      Snohomish      1       0  53061        48
# 31 2020-01-30       Illinois           Cook      2       0  17031        14
# 32 2020-01-30        Arizona       Maricopa      1       0   4013         3
# 33 2020-01-31        Arizona       Maricopa      1       0   4013         3
# 34 2020-01-31     California    Los Angeles      1       0   6037         5
# 35 2020-01-31     California         Orange      1       0   6059         5
# 36 2020-01-31     California    Santa Clara      1       0   6085         5
# 37 2020-01-31       Illinois           Cook      2       0  17031        14
# 38 2020-01-31     Washington      Snohomish      1       0  53061        48
# 39 2020-02-01     California         Orange      1       0   6059         5
# 40 2020-02-01        Arizona       Maricopa      1       0   4013         3
# 41 2020-02-01       Illinois           Cook      2       0  17031        14
# 42 2020-02-01     California    Los Angeles      1       0   6037         5
# 43 2020-02-01  Massachusetts        Suffolk      1       0  25025        22
# 44 2020-02-01     Washington      Snohomish      1       0  53061        48
# 45 2020-02-01     California    Santa Clara      1       0   6085         5
# 46 2020-02-02        Arizona       Maricopa      1       0   4013         3
# 47 2020-02-02     California    Los Angeles      1       0   6037         5
# 48 2020-02-02     California         Orange      1       0   6059         5
# 49 2020-02-02     California  San Francisco      2       0   6075         5
# 50 2020-02-02     California    Santa Clara      2       0   6085         5
# 51 2020-02-02       Illinois           Cook      2       0  17031        14
# 52 2020-02-02  Massachusetts        Suffolk      1       0  25025        22
# 53 2020-02-02     Washington      Snohomish      1       0  53061        48
# 54 2020-02-03     California    Los Angeles      1       0   6037         5
# 55 2020-02-03        Arizona       Maricopa      1       0   4013         3
# 56 2020-02-03     California         Orange      1       0   6059         5
# 57 2020-02-03     California  San Francisco      2       0   6075         5
# 58 2020-02-03     California    Santa Clara      2       0   6085         5
# 59 2020-02-03       Illinois           Cook      2       0  17031        14
#
#     county_id  full_date  date_id  case_id
# 0        2989 2020-01-21        1        1
# 1        2989 2020-01-22        2        2
# 2        2989 2020-01-23        3        3
# 3         613 2020-01-24        4        4
# 4        2989 2020-01-24        4        5
# 5         219 2020-01-25        5        6
# 6         613 2020-01-25        5        7
# 7        2989 2020-01-25        5        8
# 8         107 2020-01-26        6        9
# 9         208 2020-01-26        6       10
# 10        219 2020-01-26        6       11
# 11        613 2020-01-26        6       12
# 12       2989 2020-01-26        6       13
# 13        219 2020-01-27        7       14
# 14        107 2020-01-27        7       15
# 15        613 2020-01-27        7       16
# 16       2989 2020-01-27        7       17
# 17        208 2020-01-27        7       18
# 18        107 2020-01-28        8       19
# 19        208 2020-01-28        8       20
# 20        219 2020-01-28        8       21
# 21        613 2020-01-28        8       22
# 22       2989 2020-01-28        8       23
# 23        107 2020-01-29        9       24
# 24        208 2020-01-29        9       25
# 25        219 2020-01-29        9       26
# 26        613 2020-01-29        9       27
# 27       2989 2020-01-29        9       28
# 28        219 2020-01-30       10       29
# 29        208 2020-01-30       10       30
# 30       2989 2020-01-30       10       31
# 31        613 2020-01-30       10       32
# 32        107 2020-01-30       10       33
# 33        107 2020-01-31       11       34
# 34        208 2020-01-31       11       35
# 35        219 2020-01-31       11       36
# 36        232 2020-01-31       11       37
# 37        613 2020-01-31       11       38
# 38       2989 2020-01-31       11       39
# 39        219 2020-02-01       12       40
# 40        107 2020-02-01       12       41
# 41        613 2020-02-01       12       42
# 42        208 2020-02-01       12       43
# 43       1232 2020-02-01       12       44
# 44       2989 2020-02-01       12       45
# 45        232 2020-02-01       12       46
# 46        107 2020-02-02       13       47
# 47        208 2020-02-02       13       48
# 48        219 2020-02-02       13       49
# 49        227 2020-02-02       13       50
# 50        232 2020-02-02       13       51
# 51        613 2020-02-02       13       52
# 52       1232 2020-02-02       13       53
# 53       2989 2020-02-02       13       54
# 54        208 2020-02-03       14       55
# 55        107 2020-02-03       14       56
# 56        219 2020-02-03       14       57
# 57        227 2020-02-03       14       58
# 58        232 2020-02-03       14       59
# 59        613 2020-02-03       14       60

# %%
####
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3519450 entries, 0 to 3519449
# Data columns (total 11 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   date       datetime64[ns]
#  1   state      object
#  2   county     object
#  3   cases      int64
#  4   deaths     int64
#  5   fips       int64
#  6   state_id   int64
#  7   county_id  int64
#  8   full_date  datetime64[ns]
#  9   date_id    int64
#  10  case_id    int64
# dtypes: datetime64[ns](2), int64(7), object(2)
# memory usage: 322.2+ MB

# %%
####
fact_table = fact_table.drop(columns=['date','full_date','state','county','fips'])
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3519450 entries, 0 to 3519449
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   cases      int64
#  1   deaths     int64
#  2   state_id   int64
#  3   county_id  int64
#  4   date_id    int64
#  5   case_id    int64
# dtypes: int64(6)
# memory usage: 188.0 MB

# %%
# reindex columns for export
fact_table = fact_table.reindex(columns=['case_id','date_id','state_id','county_id','cases','deaths'])

# %%
#####
fact_table.head(60)
# Out:
#     case_id  date_id  state_id  county_id  cases  deaths
# 0         1        1        48       2989      1       0
# 1         2        2        48       2989      1       0
# 2         3        3        48       2989      1       0
# 3         4        4        14        613      1       0
# 4         5        4        48       2989      1       0
# 5         6        5         5        219      1       0
# 6         7        5        14        613      1       0
# 7         8        5        48       2989      1       0
# 8         9        6         3        107      1       0
# 9        10        6         5        208      1       0
# 10       11        6         5        219      1       0
# 11       12        6        14        613      1       0
# 12       13        6        48       2989      1       0
# 13       14        7         5        219      1       0
# 14       15        7         3        107      1       0
# 15       16        7        14        613      1       0
# 16       17        7        48       2989      1       0
# 17       18        7         5        208      1       0
# 18       19        8         3        107      1       0
# 19       20        8         5        208      1       0
# 20       21        8         5        219      1       0
# 21       22        8        14        613      1       0
# 22       23        8        48       2989      1       0
# 23       24        9         3        107      1       0
# 24       25        9         5        208      1       0
# 25       26        9         5        219      1       0
# 26       27        9        14        613      1       0
# 27       28        9        48       2989      1       0
# 28       29       10         5        219      1       0
# 29       30       10         5        208      1       0
# 30       31       10        48       2989      1       0
# 31       32       10        14        613      2       0
# 32       33       10         3        107      1       0
# 33       34       11         3        107      1       0
# 34       35       11         5        208      1       0
# 35       36       11         5        219      1       0
# 36       37       11         5        232      1       0
# 37       38       11        14        613      2       0
# 38       39       11        48       2989      1       0
# 39       40       12         5        219      1       0
# 40       41       12         3        107      1       0
# 41       42       12        14        613      2       0
# 42       43       12         5        208      1       0
# 43       44       12        22       1232      1       0
# 44       45       12        48       2989      1       0
# 45       46       12         5        232      1       0
# 46       47       13         3        107      1       0
# 47       48       13         5        208      1       0
# 48       49       13         5        219      1       0
# 49       50       13         5        227      2       0
# 50       51       13         5        232      2       0
# 51       52       13        14        613      2       0
# 52       53       13        22       1232      1       0
# 53       54       13        48       2989      1       0
# 54       55       14         5        208      1       0
# 55       56       14         3        107      1       0
# 56       57       14         5        219      1       0
# 57       58       14         5        227      2       0
# 58       59       14         5        232      2       0
# 59       60       14        14        613      2       0

# %%
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3519450 entries, 0 to 3519449
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   case_id    int64
#  1   date_id    int64
#  2   state_id   int64
#  3   county_id  int64
#  4   cases      int64
#  5   deaths     int64
# dtypes: int64(6)
# memory usage: 188.0 MB

# %%
# create fact CSV
if switch:
    fact_table.to_csv('/Users/chriskimmons/My_Projects/NYT_COV/star_schema_files/factCases.csv', index=False)
    print('file created')
# Out:
# file created

# %%
####
fact_table.head()
# Out:
#    case_id  date_id  state_id  county_id  cases  deaths
# 0        1        1        48       2989      1       0
# 1        2        2        48       2989      1       0
# 2        3        3        48       2989      1       0
# 3        4        4        14        613      1       0
# 4        5        4        48       2989      1       0

# %%
fact_table.query('county_id == 1601')
# Out:
#          case_id  date_id  state_id  county_id  cases  deaths
# 7109        7110       61        26       1601      1       0
# 8223        8224       62        26       1601      1       0
# 9445        9446       63        26       1601      1       0
# 10792      10793       64        26       1601      1       0
# 12317      12318       65        26       1601      3       0
# ...          ...      ...       ...        ...    ...     ...
# 3504325  3504326     1154        26       1601  54747     960
# 3507589  3507590     1155        26       1601  54747     960
# 3510835  3510836     1156        26       1601  54882     960
# 3515060  3515061     1157        26       1601  54882     960
# 3516902  3516903     1158        26       1601  54882     960
#
# [1098 rows x 6 columns]

# %%
####
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3519450 entries, 0 to 3519449
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   case_id    int64
#  1   date_id    int64
#  2   state_id   int64
#  3   county_id  int64
#  4   cases      int64
#  5   deaths     int64
# dtypes: int64(6)
# memory usage: 188.0 MB

# %%
####
county_pop_df.query('state == county')
# Out:
#                     county  state_id                 state   fips  base2020  \
# 115               Arkansas         4              Arkansas   5001     17149
# 549                 Hawaii        12                Hawaii  15001    200629
# 578                  Idaho        13                 Idaho  16049     16541
# 839                   Iowa        16                  Iowa  19095     16662
# 1863              New York        33              New York  36061   1694251
# 2191              Oklahoma        37              Oklahoma  40109    796292
# 2807                  Utah        45                  Utah  49049    659399
# 3238  District of Columbia         9  District of Columbia  11001    689545
#
#       county_id
# 115         115
# 549         549
# 578         578
# 839         839
# 1863       1863
# 2191       2191
# 2807       2807
# 3238       3238

# %%
# where to build the extra coulnms
fact_table =fact_table.sort_values(['state_id','county_id'])

mask = (fact_table['state_id'].shift() != fact_table['state_id']) | (fact_table['county_id'].shift() != fact_table['county_id'])

fact_table['new_cases'] = fact_table.cases.diff()
fact_table.loc[mask, 'new_cases'] = None

# fact_table.new_cases = fact_table.new_cases.fillna(0)
fact_table = fact_table.sort_values(['date_id','state_id','county_id'])
fact_table.head(60)

fact_table['cases_7_day_avg'] = fact_table.new_cases.rolling(7).sum() / 7
fact_table['infection_level'] = fact_table.new_cases.rolling(14).sum()

# %%
# fact_table = fact_table.fillna(0)

# %%
# if switch:
#     fact_table.to_csv('/Users/chriskimmons/My_Projects/NYT_COV/star_schema_files/factCasesfull.csv')

# %%
# fact_table[3000000:3000010]

# %%
# all_counties_df.info()

# %% [markdown]
# Testing

# %%
#####
f = fact_table.loc[(fact_table.date_id == max(fact_table.date_id))]
f
# Out:
#          case_id  date_id  state_id  county_id  cases  deaths  new_cases  \
# 3518420  3518421     1158         1          0  19812     235        0.0
# 3518421  3518422     1158         1          1  70040     730        0.0
# 3518422  3518423     1158         1          2   7509     113        0.0
# 3518423  3518424     1158         1          3   8105     111        0.0
# 3518424  3518425     1158         1          4  18747     261        0.0
# ...          ...      ...       ...        ...    ...     ...        ...
# 3517592  3517593     1158        55       3232   1054       5        0.0
# 3517591  3517592     1158        55       3233  10792      71        0.0
# 3516316  3516317     1158        56       3235    422       0        0.0
# 3516330  3516331     1158        56       3236  12574      40        0.0
# 3516315  3516316     1158        56       3237    399       1        0.0
#
#          cases_7_day_avg  infection_level
# 3518420         0.000000             36.0
# 3518421         0.000000             33.0
# 3518422         0.000000             27.0
# 3518423         0.000000             24.0
# 3518424         0.000000             16.0
# ...                  ...              ...
# 3517592         5.142857             71.0
# 3517591         4.714286             68.0
# 3516316         2.571429             64.0
# 3516330         0.000000             56.0
# 3516315         0.000000             48.0
#
# [3250 rows x 9 columns]

# %%
####
# fact_table.loc[(fact_table.date_id == max(fact_table.date_id)) & (fact_table.state_id == 49)].cases.sum()

# %%
###
g = all_counties_df.query('date == "2023-03-23"')
g
# Out:
#               date     state            county   cases  deaths   fips
# 3515334 2023-03-23  Oklahoma             Craig    6042      65  40035
# 3515335 2023-03-23  Oklahoma          Comanche   39398     438  40031
# 3515336 2023-03-23  Oklahoma            Cotton    1716      40  40033
# 3515337 2023-03-23  Oklahoma             Creek   22900     365  40037
# 3515338 2023-03-23      Ohio             Logan   12814     180  39091
# ...            ...       ...               ...     ...     ...    ...
# 3518579 2023-03-23  Kentucky         McCracken   24038     316  21145
# 3518580 2023-03-23  Kentucky             Mason    6346     119  21161
# 3518581 2023-03-23  Kentucky            Martin    4251      54  21159
# 3518582 2023-03-23  Kentucky            Butler    4783      60  21031
# 3518583 2023-03-23  Missouri  Kansas City Area  335497    4455   3800
#
# [3250 rows x 6 columns]

# %%
####
all_counties_df.query('date == "2023-03-23" & county == "Unknown"').cases.sum()
# Out:
# 481805

# %%
#####
giant = pd.merge(f,g,on='cases',how='outer', )

# %%
giant.head(60)
# Out:
#     case_id  date_id  state_id  county_id   cases  deaths_x  new_cases  \
# 0   3518421     1158         1          0   19812       235        0.0
# 1   3518422     1158         1          1   70040       730        0.0
# 2   3518423     1158         1          2    7509       113        0.0
# 3   3518424     1158         1          3    8105       111        0.0
# 4   3518425     1158         1          4   18747       261        0.0
# 5   3518426     1158         1          5    3042        54        0.0
# 6   3518396     1158         1          6    6568       132        0.0
# 7   3518411     1158         1          7   41502       683        0.0
# 8   3518395     1158         1          8   10890       181        0.0
# 9   3518377     1158         1          9    6772       135        0.0
# 10  3518363     1158         1         10   13028       232        0.0
# 11  3518364     1158         1         11    2259        63        0.0
# 12  3518365     1158         1         12    8560       115        0.0
# 13  3518366     1158         1         13    5179        94        0.0
# 14  3518366     1158         1         13    5179        94        0.0
# 15  3517920     1158        43       2510    5179        74        0.0
# 16  3517920     1158        43       2510    5179        74        0.0
# 17  3518368     1158         1         14    4437        76        0.0
# 18  3518383     1158         1         15   17216       249        0.0
# 19  3518369     1158         1         16   21362       279        0.0
# 20  3518370     1158         1         17    3615        76        0.0
# 21  3518371     1158         1         18    3782        64        0.0
# 22  3518372     1158         1         19   11823       280        0.0
# 23  3518373     1158         1         20    4745       111        0.0
# 24  3518374     1158         1         21   31575       400        0.0
# 25  3518375     1158         1         22   16557       245        0.0
# 26  3518376     1158         1         23   11050       260        0.0
# 27  3518378     1158         1         24   22552       354        0.0
# 28  3518393     1158         1         25   29896       364        0.0
# 29  3518379     1158         1         26   12432       193        0.0
# 30  3518380     1158         1         27   34266       695        0.0
# 31  3518381     1158         1         28    5900       100        0.0
# 32  3518382     1158         1         29   12078       154        0.0
# 33  3518420     1158         1         30    7979       174        0.0
# 34  3518367     1158         1         31    2320        54        0.0
# 35  3518419     1158         1         32    5742       110        0.0
# 36  3518401     1158         1         33    5879        79        0.0
# 37  3518591     1158         1         34   32753       532        0.0
# 38  3518592     1158         1         35   18419       282        0.0
# 39  3518593     1158         1         36  239299      2536        0.0
# 40  3518594     1158         1         37    4749        97        0.0
# 41  3518595     1158         1         38   30476       421        0.0
# 42  3518596     1158         1         39    9416       188        0.0
# 43  3518498     1158         1         40   47764       406        0.0
# 44  3518564     1158         1         41   32225       323        0.0
# 45  3518497     1158         1         42    3384        83        0.0
# 46  3518428     1158         1         43    5309        90        0.0
# 47  3518397     1158         1         44  116344      1067        0.0
# 48  3518398     1158         1         45    6104       116        0.0
# 49  3518399     1158         1         46   10134       163        0.0
# 50  3518400     1158         1         47   33032       411        0.0
# 51  3518402     1158         1         48  135201      1804        0.0
# 52  3518417     1158         1         49    6758       106        0.0
# 53  3518417     1158         1         49    6758       106        0.0
# 54  3517014     1158        24       1336    6758        24        5.0
# 55  3517014     1158        24       1336    6758        24        5.0
# 56  3518403     1158         1         50   74047      1014        0.0
# 57  3518404     1158         1         51   46671       553        0.0
# 58  3518405     1158         1         52    2683        50        0.0
# 59  3518406     1158         1         53    6364       122        0.0
#
#     cases_7_day_avg  infection_level       date      state      county  \
# 0          0.000000             36.0 2023-03-23    Alabama     Autauga
# 1          0.000000             33.0 2023-03-23    Alabama     Baldwin
# 2          0.000000             27.0 2023-03-23    Alabama     Barbour
# 3          0.000000             24.0 2023-03-23    Alabama        Bibb
# 4          0.000000             16.0 2023-03-23    Alabama      Blount
# 5          0.000000              0.0 2023-03-23    Alabama     Bullock
# 6          0.000000              0.0 2023-03-23    Alabama      Butler
# 7          0.000000              0.0 2023-03-23    Alabama     Calhoun
# 8          0.000000              0.0 2023-03-23    Alabama    Chambers
# 9          0.000000              0.0 2023-03-23    Alabama    Cherokee
# 10         0.000000              0.0 2023-03-23    Alabama     Chilton
# 11         0.000000              0.0 2023-03-23    Alabama     Choctaw
# 12         0.000000              0.0 2023-03-23    Alabama      Clarke
# 13         0.000000              0.0 2023-03-23  Tennessee  Sequatchie
# 14         0.000000              0.0 2023-03-23    Alabama        Clay
# 15         0.000000              0.0 2023-03-23  Tennessee  Sequatchie
# 16         0.000000              0.0 2023-03-23    Alabama        Clay
# 17         0.000000              0.0 2023-03-23    Alabama    Cleburne
# 18         0.000000              0.0 2023-03-23    Alabama      Coffee
# 19         0.000000              0.0 2023-03-23    Alabama     Colbert
# 20         0.000000              0.0 2023-03-23    Alabama     Conecuh
# 21         0.000000              0.0 2023-03-23    Alabama       Coosa
# 22         0.000000              0.0 2023-03-23    Alabama   Covington
# 23         0.000000              0.0 2023-03-23    Alabama    Crenshaw
# 24         0.000000              0.0 2023-03-23    Alabama     Cullman
# 25         0.000000              0.0 2023-03-23    Alabama        Dale
# 26         0.000000              0.0 2023-03-23    Alabama      Dallas
# 27         0.000000              0.0 2023-03-23    Alabama      DeKalb
# 28         0.000000              0.0 2023-03-23    Alabama      Elmore
# 29         0.000000              0.0 2023-03-23    Alabama    Escambia
# 30         0.000000              0.0 2023-03-23    Alabama      Etowah
# 31         0.000000              0.0 2023-03-23    Alabama     Fayette
# 32         0.000000              0.0 2023-03-23    Alabama    Franklin
# 33         0.000000              0.0 2023-03-23    Alabama      Geneva
# 34         0.000000              0.0 2023-03-23    Alabama      Greene
# 35         0.000000              0.0 2023-03-23    Alabama        Hale
# 36         0.000000              0.0 2023-03-23    Alabama       Henry
# 37         0.000000              0.0 2023-03-23    Alabama     Houston
# 38         0.000000              0.0 2023-03-23    Alabama     Jackson
# 39         0.000000              0.0 2023-03-23    Alabama   Jefferson
# 40         0.000000              0.0 2023-03-23    Alabama       Lamar
# 41         0.000000              0.0 2023-03-23    Alabama  Lauderdale
# 42         0.000000              0.0 2023-03-23    Alabama    Lawrence
# 43         0.000000              0.0 2023-03-23    Alabama         Lee
# 44         0.000000              0.0 2023-03-23    Alabama   Limestone
# 45         0.000000              0.0 2023-03-23    Alabama     Lowndes
# 46         0.000000              0.0 2023-03-23    Alabama       Macon
# 47         0.000000              0.0 2023-03-23    Alabama     Madison
# 48         0.000000              0.0 2023-03-23    Alabama     Marengo
# 49         0.000000              0.0 2023-03-23    Alabama      Marion
# 50         0.000000              0.0 2023-03-23    Alabama    Marshall
# 51         0.000000              0.0 2023-03-23    Alabama      Mobile
# 52         0.000000              0.0 2023-03-23  Minnesota       Dodge
# 53         0.000000              0.0 2023-03-23    Alabama      Monroe
# 54        45.714286            487.0 2023-03-23  Minnesota       Dodge
# 55        45.714286            487.0 2023-03-23    Alabama      Monroe
# 56         0.000000              0.0 2023-03-23    Alabama  Montgomery
# 57         0.000000              0.0 2023-03-23    Alabama      Morgan
# 58         0.000000              0.0 2023-03-23    Alabama       Perry
# 59         0.000000              0.0 2023-03-23    Alabama     Pickens
#
#     deaths_y   fips
# 0        235   1001
# 1        730   1003
# 2        113   1005
# 3        111   1007
# 4        261   1009
# 5         54   1011
# 6        132   1013
# 7        683   1015
# 8        181   1017
# 9        135   1019
# 10       232   1021
# 11        63   1023
# 12       115   1025
# 13        74  47153
# 14        94   1027
# 15        74  47153
# 16        94   1027
# 17        76   1029
# 18       249   1031
# 19       279   1033
# 20        76   1035
# 21        64   1037
# 22       280   1039
# 23       111   1041
# 24       400   1043
# 25       245   1045
# 26       260   1047
# 27       354   1049
# 28       364   1051
# 29       193   1053
# 30       695   1055
# 31       100   1057
# 32       154   1059
# 33       174   1061
# 34        54   1063
# 35       110   1065
# 36        79   1067
# 37       532   1069
# 38       282   1071
# 39      2536   1073
# 40        97   1075
# 41       421   1077
# 42       188   1079
# 43       406   1081
# 44       323   1083
# 45        83   1085
# 46        90   1087
# 47      1067   1089
# 48       116   1091
# 49       163   1093
# 50       411   1095
# 51      1804   1097
# 52        24  27039
# 53       106   1099
# 54        24  27039
# 55       106   1099
# 56      1014   1101
# 57       553   1103
# 58        50   1105
# 59       122   1107

# %%
f.query('state_id == 53')
# Out:
#          case_id  date_id  state_id  county_id  cases  deaths  new_cases  \
# 3518447  3518448     1158        53       3290   8309      34        0.0
#
#          cases_7_day_avg  infection_level
# 3518447         6.857143             85.0

# %%
g.query('state == "American Samoa"')
# Out:
#               date           state   county  cases  deaths  fips
# 3517581 2023-03-23  American Samoa  Unknown   8309      34    60

# %%
giant.query('county == "Unknown"')
# Out:
#       case_id  date_id  state_id  county_id   cases  deaths_x  new_cases  \
# 107   3518443     1158         2       3240    1822         0        0.0
# 109   3516806     1158        26       1514    1822        49        0.0
# 175   3518557     1158         4        140   27112       583        0.0
# 177   3518155     1158        52       3289   27112      5848       18.0
# 252   3518535     1158         4       3242   33674         0        0.0
# 401   3518862     1158         6       3244       0        25        0.0
# 402   3518862     1158         6       3244       0        25        0.0
# 403   3518862     1158         6       3244       0        25        0.0
# 404   3518862     1158         6       3244       0        25        0.0
# 405   3518913     1158        12       3249       0        77        0.0
# 406   3518913     1158        12       3249       0        77        0.0
# 407   3518913     1158        12       3249       0        77        0.0
# 408   3518913     1158        12       3249       0        77        0.0
# 409   3519049     1158        14       3251       0      2796        0.0
# 410   3519049     1158        14       3251       0      2796        0.0
# 411   3519049     1158        14       3251       0      2796        0.0
# 412   3519049     1158        14       3251       0      2796        0.0
# 413   3516308     1158        35       3272       0       216        0.0
# 414   3516308     1158        35       3272       0       216        0.0
# 415   3516308     1158        35       3272       0       216        0.0
# 416   3516308     1158        35       3272       0       216        0.0
# 426   3518669     1158         7       3245    3270         4       -7.0
# 428   3517667     1158        44       2756    3270        81        0.0
# 432   3518674     1158         8       3246    1087         0        0.0
# 516   3518738     1158        10       3247     280       398        0.0
# 731   3518888     1158        11       3248   12098         1        0.0
# 735   3518910     1158        12        551       1         0        0.0
# 736   3518910     1158        12        551       1         0        0.0
# 738   3519075     1158        15       3252       1       162        1.0
# 739   3519075     1158        15       3252       1       162        1.0
# 741   3519309     1158        16       3253       1         0        0.0
# 742   3519309     1158        16       3253       1         0        0.0
# 1480  3517244     1158        18       3255    2505         0        0.0
# 1555  3517179     1158        19       3256    1243         0        0.0
# 1575  3517158     1158        20       3257      18         0        0.0
# 1612  3517120     1158        22       3259  202658        30      458.0
# 1704  3517004     1158        23       3260   16486        34      -83.0
# 1800  3516957     1158        24       3261     864       397        4.0
# 2221  3516598     1158        29       3266   11551         0     1112.0
# 2232  3516600     1158        30       3267    2352         0        1.0
# 2254  3516565     1158        31       3268    1644         0       -1.0
# 2292  3516530     1158        32       3269     529         0        0.0
# 2678  3518319     1158        37       3274     735         0      583.0
# 2711  3518268     1158        38       3275       4         0        0.0
# 2790  3518111     1158        40       3277   30079         0      -42.0
# 3004  3517909     1158        43       3280   38679       249        1.0
# 3225  3517665     1158        44       3281   10766         0     -242.0
# 3251  3517615     1158        45       3282    5953        97        7.0
# 3264  3517598     1158        46       3283    3208        22      247.0
# 3392  3517437     1158        47       3284     894         0      454.0
# 3430  3517440     1158        48       3285    1906         0        0.0
# 3432  3517336     1158        51       3147    1906        23        0.0
# 3646  3518448     1158        53       3290    8309        34        0.0
# 3647  3518922     1158        54       3291   62077       416        0.0
#
#       cases_7_day_avg  infection_level       date           state   county  \
# 107          0.000000              0.0 2023-03-23          Alaska  Unknown
# 109          0.000000              0.0 2023-03-23          Alaska  Unknown
# 175          0.000000              0.0 2023-03-23     Puerto Rico  Unknown
# 177          8.000000             95.0 2023-03-23     Puerto Rico  Unknown
# 252          0.000000              0.0 2023-03-23        Arkansas  Unknown
# 401          0.428571             23.0 2023-03-23    North Dakota  Unknown
# 402          0.428571             23.0 2023-03-23        Colorado  Unknown
# 403          0.428571             23.0 2023-03-23          Hawaii  Unknown
# 404          0.428571             23.0 2023-03-23        Illinois  Unknown
# 405          0.000000              0.0 2023-03-23    North Dakota  Unknown
# 406          0.000000              0.0 2023-03-23        Colorado  Unknown
# 407          0.000000              0.0 2023-03-23          Hawaii  Unknown
# 408          0.000000              0.0 2023-03-23        Illinois  Unknown
# 409        117.285714            997.0 2023-03-23    North Dakota  Unknown
# 410        117.285714            997.0 2023-03-23        Colorado  Unknown
# 411        117.285714            997.0 2023-03-23          Hawaii  Unknown
# 412        117.285714            997.0 2023-03-23        Illinois  Unknown
# 413          0.000000              0.0 2023-03-23    North Dakota  Unknown
# 414          0.000000              0.0 2023-03-23        Colorado  Unknown
# 415          0.000000              0.0 2023-03-23          Hawaii  Unknown
# 416          0.000000              0.0 2023-03-23        Illinois  Unknown
# 426          8.285714            128.0 2023-03-23     Connecticut  Unknown
# 428          0.000000            217.0 2023-03-23     Connecticut  Unknown
# 432          0.857143            126.0 2023-03-23        Delaware  Unknown
# 516          0.000000              0.0 2023-03-23         Florida  Unknown
# 731          0.000000              0.0 2023-03-23         Georgia  Unknown
# 735          0.000000              0.0 2023-03-23         Indiana  Unknown
# 736          0.000000              0.0 2023-03-23            Iowa  Unknown
# 738          0.142857              1.0 2023-03-23         Indiana  Unknown
# 739          0.142857              1.0 2023-03-23            Iowa  Unknown
# 741          0.000000              0.0 2023-03-23         Indiana  Unknown
# 742          0.000000              0.0 2023-03-23            Iowa  Unknown
# 1480         0.000000              0.0 2023-03-23        Kentucky  Unknown
# 1555         0.000000              0.0 2023-03-23       Louisiana  Unknown
# 1575         0.000000              0.0 2023-03-23           Maine  Unknown
# 1612       251.571429           2443.0 2023-03-23   Massachusetts  Unknown
# 1704         0.000000              0.0 2023-03-23        Michigan  Unknown
# 1800        31.142857            262.0 2023-03-23       Minnesota  Unknown
# 2221       158.857143           1112.0 2023-03-23          Nevada  Unknown
# 2232        24.000000           1348.0 2023-03-23   New Hampshire  Unknown
# 2254        14.857143            404.0 2023-03-23      New Jersey  Unknown
# 2292         3.142857            107.0 2023-03-23      New Mexico  Unknown
# 2678       139.285714            961.0 2023-03-23        Oklahoma  Unknown
# 2711         0.000000              0.0 2023-03-23          Oregon  Unknown
# 2790        74.571429            522.0 2023-03-23    Rhode Island  Unknown
# 3004         0.142857              1.0 2023-03-23       Tennessee  Unknown
# 3225       -34.571429           -242.0 2023-03-23           Texas  Unknown
# 3251        47.285714            830.0 2023-03-23            Utah  Unknown
# 3264        35.285714            247.0 2023-03-23         Vermont  Unknown
# 3392        64.857143            454.0 2023-03-23        Virginia  Unknown
# 3430         0.000000              0.0 2023-03-23      Washington  Unknown
# 3432         0.000000              0.0 2023-03-23      Washington  Unknown
# 3646         6.857143             85.0 2023-03-23  American Samoa  Unknown
# 3647         6.142857             80.0 2023-03-23            Guam  Unknown
#
#       deaths_y  fips
# 107          0     2
# 109          0     2
# 175       5848    72
# 177       5848    72
# 252          0     5
# 401        216    38
# 402         25     8
# 403         77    15
# 404       2796    17
# 405        216    38
# 406         25     8
# 407         77    15
# 408       2796    17
# 409        216    38
# 410         25     8
# 411         77    15
# 412       2796    17
# 413        216    38
# 414         25     8
# 415         77    15
# 416       2796    17
# 426          4     9
# 428          4     9
# 432          0    10
# 516        398    12
# 731          1    13
# 735        162    18
# 736          0    19
# 738        162    18
# 739          0    19
# 741        162    18
# 742          0    19
# 1480         0    21
# 1555         0    22
# 1575         0    23
# 1612        30    25
# 1704        34    26
# 1800       397    27
# 2221         0    32
# 2232         0    33
# 2254         0    34
# 2292         0    35
# 2678         0    40
# 2711         0    41
# 2790         0    44
# 3004       249    47
# 3225         0    48
# 3251        97    49
# 3264        22    50
# 3392         0    51
# 3430         0    53
# 3432         0    53
# 3646        34    60
# 3647       416    66

# %%
all_counties_df.loc[all_counties_df.fips.isna()]
# Out:
# Empty DataFrame
# Columns: [date, state, county, cases, deaths, fips]
# Index: []
